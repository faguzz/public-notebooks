# %%
import pandas as pd
import numpy as np
import hyperopt
import os
import sys
import csv

from time import time

from hyperopt import hp, fmin, tpe
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Loading data

# %%
df = pd.read_csv('data/manipulated_train.csv')

# %%
X = df.drop(['SalePrice'], axis=1)
y = df['SalePrice']

# %%
X.shape
# Out:
# (1460, 79)

# %% [markdown]
# ### Setting paratemers

# %%
# Test parameters
max_evals = 200
run_counter = 0
num_cv = 10
n_jobs = -1
output_log_file = '~/temp/hyperopt-et.csv'

# %%
et = ExtraTreesRegressor()
et.get_params()
# Out:
# {'bootstrap': False,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_split': 1e-07,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 10,
#  'n_jobs': 1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Hyperparameters space
space = (
    hp.uniform('max_depth', 5, 30),
    hp.uniform('max_features', 0.1, 1),
    hp.uniform('min_samples_leaf', 1, 10)
)

# %% [markdown]
# ### Function run_wrapper
#
# Just a function for counting and logging experiments, that is called by the hyperopt.fmin(). It also calls the run_test(), the function that indeed execute the experiment for the input parameters.

# %%
def run_wrapper(params):
    global run_counter
    global o_f
    
    run_counter += 1
    print "=============================="
    print "run", run_counter
    
    s = time()
    r2score = run_test(params)
    
    print
    print "1 - R2 score:", r2score
    print "elapsed: {}s \n".format(int(round(time() - s)))
    
    writer.writerow([r2score] + list(params))
    o_f.flush()
    return r2score

# %% [markdown]
# ### Function run_test
#
# The function that receives the parameters, execute the test and return the results. I am using a cross-validation for obtaining the score, and returning it for being optmized by hyperopt.fmin() (therefore I subtracted 1 - score).

# %%
def run_test(params):
    max_depth, max_features, min_samples_leaf = params
    max_depth = int(max_depth)
    min_samples_leaf = int(min_samples_leaf)
    
    print "max_depth:", max_depth
    print "max_features:", max_features
    print "min_samples_leaf:", min_samples_leaf
    
    et = ExtraTreesRegressor(max_depth=max_depth,
                             max_features=max_features,
                             min_samples_leaf=min_samples_leaf,
                             n_estimators=100,
                             random_state=66)
    
    cvs = cross_val_score(et, X, y,
                          cv=num_cv,
                          n_jobs=n_jobs)
    
    return 1 - np.median(cvs)

# %% [markdown]
# ### Main function
#
# Just some logging and calling the hyperopt.fmin(). In the end, it obtains the best parameters -- the ones that minimizes the objective function.

# %%
if __name__ == '__main__':
    
    headers = 'r2score max_depth max_features min_samples_leaf'.split()
    o_f = open(output_log_file, 'wb')
    writer = csv.writer(o_f)
    writer.writerow(headers)
    
    start_time = time()
    best = fmin(run_wrapper, space, algo=tpe.suggest, max_evals=max_evals)
    end_time = time()
    
    print "Seconds passed:", int(round(end_time - start_time))
    print best
# Out:
# ==============================
# run 1
# max_depth: 23
# max_features: 0.148196167325
# min_samples_leaf: 3
#
# 1 - R2 score: 0.140337621005
# elapsed: 2s
#
# ==============================
# run 2
# max_depth: 6
# max_features: 0.896749788191
# min_samples_leaf: 8
#
# 1 - R2 score: 0.155901346291
# elapsed: 3s
#
# ==============================
# run 3
# max_depth: 20
# max_features: 0.519160108947
# min_samples_leaf: 5
#
# 1 - R2 score: 0.126570695644
# elapsed: 3s
#
# ==============================
# run 4
# max_depth: 24
# max_features: 0.937054774532
# min_samples_leaf: 8
#
# 1 - R2 score: 0.132147137434
# elapsed: 4s
#
# ==============================
# run 5
# max_depth: 22
# max_features: 0.645266070546
# min_samples_leaf: 6
#
# 1 - R2 score: 0.130512717559
# elapsed: 3s
#
# ==============================
# run 6
# max_depth: 8
# max_features: 0.239631267635
# min_samples_leaf: 7
#
# 1 - R2 score: 0.153455064729
# elapsed: 2s
#
# ==============================
# run 7
# max_depth: 16
# max_features: 0.705697289706
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124492090008
# elapsed: 4s
#
# ==============================
# run 8
# max_depth: 29
# max_features: 0.541683747933
# min_samples_leaf: 7
#
# 1 - R2 score: 0.132674373792
# elapsed: 3s
#
# ==============================
# run 9
# max_depth: 22
# max_features: 0.805593595924
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115403726725
# elapsed: 5s
#
# ==============================
# run 10
# max_depth: 20
# max_features: 0.144774587553
# min_samples_leaf: 2
#
# 1 - R2 score: 0.1337594844
# elapsed: 2s
#
# ==============================
# run 11
# max_depth: 19
# max_features: 0.650515208288
# min_samples_leaf: 6
#
# 1 - R2 score: 0.130995452955
# elapsed: 3s
#
# ==============================
# run 12
# max_depth: 23
# max_features: 0.175800575569
# min_samples_leaf: 5
#
# 1 - R2 score: 0.148530592998
# elapsed: 2s
#
# ==============================
# run 13
# max_depth: 14
# max_features: 0.464560216862
# min_samples_leaf: 3
#
# 1 - R2 score: 0.119818343111
# elapsed: 3s
#
# ==============================
# run 14
# max_depth: 28
# max_features: 0.838364493113
# min_samples_leaf: 5
#
# 1 - R2 score: 0.127748252974
# elapsed: 4s
#
# ==============================
# run 15
# max_depth: 9
# max_features: 0.755213673534
# min_samples_leaf: 7
#
# 1 - R2 score: 0.136949187782
# elapsed: 3s
#
# ==============================
# run 16
# max_depth: 21
# max_features: 0.848692965623
# min_samples_leaf: 5
#
# 1 - R2 score: 0.126970124677
# elapsed: 4s
#
# ==============================
# run 17
# max_depth: 21
# max_features: 0.405003862248
# min_samples_leaf: 2
#
# 1 - R2 score: 0.119061427348
# elapsed: 4s
#
# ==============================
# run 18
# max_depth: 9
# max_features: 0.380721974783
# min_samples_leaf: 9
#
# 1 - R2 score: 0.143514372761
# elapsed: 3s
#
# ==============================
# run 19
# max_depth: 9
# max_features: 0.390753664435
# min_samples_leaf: 7
#
# 1 - R2 score: 0.141489660047
# elapsed: 3s
#
# ==============================
# run 20
# max_depth: 23
# max_features: 0.702831489099
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123931041928
# elapsed: 5s
#
# ==============================
# run 21
# max_depth: 26
# max_features: 0.293674433016
# min_samples_leaf: 1
#
# 1 - R2 score: 0.118410005261
# elapsed: 4s
#
# ==============================
# run 22
# max_depth: 26
# max_features: 0.27039732988
# min_samples_leaf: 1
#
# 1 - R2 score: 0.119081597826
# elapsed: 4s
#
# ==============================
# run 23
# max_depth: 26
# max_features: 0.980955259643
# min_samples_leaf: 1
#
# 1 - R2 score: 0.10978548893
# elapsed: 8s
#
# ==============================
# run 24
# max_depth: 17
# max_features: 0.970629240285
# min_samples_leaf: 4
#
# 1 - R2 score: 0.125902457471
# elapsed: 5s
#
# ==============================
# run 25
# max_depth: 14
# max_features: 0.987634958136
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111321009581
# elapsed: 7s
#
# ==============================
# run 26
# max_depth: 12
# max_features: 0.978727675277
# min_samples_leaf: 1
#
# 1 - R2 score: 0.112916480764
# elapsed: 7s
#
# ==============================
# run 27
# max_depth: 15
# max_features: 0.904105294476
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114369086613
# elapsed: 8s
#
# ==============================
# run 28
# max_depth: 12
# max_features: 0.986517989033
# min_samples_leaf: 4
#
# 1 - R2 score: 0.127306188653
# elapsed: 4s
#
# ==============================
# run 29
# max_depth: 18
# max_features: 0.869226021282
# min_samples_leaf: 1
#
# 1 - R2 score: 0.11431414527
# elapsed: 7s
#
# ==============================
# run 30
# max_depth: 15
# max_features: 0.602165324161
# min_samples_leaf: 1
#
# 1 - R2 score: 0.116101742167
# elapsed: 5s
#
# ==============================
# run 31
# max_depth: 11
# max_features: 0.781456331861
# min_samples_leaf: 4
#
# 1 - R2 score: 0.12447422263
# elapsed: 4s
#
# ==============================
# run 32
# max_depth: 6
# max_features: 0.931917612322
# min_samples_leaf: 4
#
# 1 - R2 score: 0.155551583162
# elapsed: 3s
#
# ==============================
# run 33
# max_depth: 25
# max_features: 0.73771746764
# min_samples_leaf: 9
#
# 1 - R2 score: 0.133049388935
# elapsed: 3s
#
# ==============================
# run 34
# max_depth: 17
# max_features: 0.985847081711
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116259074083
# elapsed: 6s
#
# ==============================
# run 35
# max_depth: 5
# max_features: 0.589449810769
# min_samples_leaf: 1
#
# 1 - R2 score: 0.175537710884
# elapsed: 2s
#
# ==============================
# run 36
# max_depth: 29
# max_features: 0.895521796068
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125125305573
# elapsed: 5s
#
# ==============================
# run 37
# max_depth: 19
# max_features: 0.814936893466
# min_samples_leaf: 8
#
# 1 - R2 score: 0.135205253818
# elapsed: 4s
#
# ==============================
# run 38
# max_depth: 15
# max_features: 0.672541748071
# min_samples_leaf: 6
#
# 1 - R2 score: 0.132172994597
# elapsed: 5s
#
# ==============================
# run 39
# max_depth: 11
# max_features: 0.931717508518
# min_samples_leaf: 2
#
# 1 - R2 score: 0.114870561089
# elapsed: 6s
#
# ==============================
# run 40
# max_depth: 13
# max_features: 0.479507231533
# min_samples_leaf: 1
#
# 1 - R2 score: 0.118607439258
# elapsed: 5s
#
# ==============================
# run 41
# max_depth: 7
# max_features: 0.576554343865
# min_samples_leaf: 3
#
# 1 - R2 score: 0.144152561433
# elapsed: 4s
#
# ==============================
# run 42
# max_depth: 16
# max_features: 0.778331771766
# min_samples_leaf: 4
#
# 1 - R2 score: 0.125942207684
# elapsed: 4s
#
# ==============================
# run 43
# max_depth: 18
# max_features: 0.877856731359
# min_samples_leaf: 6
#
# 1 - R2 score: 0.132350120186
# elapsed: 5s
#
# ==============================
# run 44
# max_depth: 25
# max_features: 0.628565873641
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118265863248
# elapsed: 6s
#
# ==============================
# run 45
# max_depth: 28
# max_features: 0.71289641209
# min_samples_leaf: 7
#
# 1 - R2 score: 0.134709352506
# elapsed: 3s
#
# ==============================
# run 46
# max_depth: 23
# max_features: 0.527201979982
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113779521482
# elapsed: 7s
#
# ==============================
# run 47
# max_depth: 20
# max_features: 0.950747624521
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124692383534
# elapsed: 7s
#
# ==============================
# run 48
# max_depth: 10
# max_features: 0.108616079672
# min_samples_leaf: 2
#
# 1 - R2 score: 0.154346953053
# elapsed: 2s
#
# ==============================
# run 49
# max_depth: 13
# max_features: 0.832952414027
# min_samples_leaf: 8
#
# 1 - R2 score: 0.13386137991
# elapsed: 4s
#
# ==============================
# run 50
# max_depth: 24
# max_features: 0.316720402017
# min_samples_leaf: 4
#
# 1 - R2 score: 0.12801020545
# elapsed: 3s
#
# ==============================
# run 51
# max_depth: 5
# max_features: 0.495340742252
# min_samples_leaf: 5
#
# 1 - R2 score: 0.180641179612
# elapsed: 2s
#
# ==============================
# run 52
# max_depth: 28
# max_features: 0.213791161087
# min_samples_leaf: 5
#
# 1 - R2 score: 0.147354147799
# elapsed: 2s
#
# ==============================
# run 53
# max_depth: 19
# max_features: 0.664507333341
# min_samples_leaf: 2
#
# 1 - R2 score: 0.114552735684
# elapsed: 4s
#
# ==============================
# run 54
# max_depth: 22
# max_features: 0.450085803114
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124075481299
# elapsed: 3s
#
# ==============================
# run 55
# max_depth: 11
# max_features: 0.998377258168
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116040732111
# elapsed: 5s
#
# ==============================
# run 56
# max_depth: 8
# max_features: 0.351763328193
# min_samples_leaf: 9
#
# 1 - R2 score: 0.149564409245
# elapsed: 2s
#
# ==============================
# run 57
# max_depth: 21
# max_features: 0.785395005843
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114999043607
# elapsed: 9s
#
# ==============================
# run 58
# max_depth: 14
# max_features: 0.914901092029
# min_samples_leaf: 2
#
# 1 - R2 score: 0.113118297889
# elapsed: 7s
#
# ==============================
# run 59
# max_depth: 16
# max_features: 0.864965916724
# min_samples_leaf: 3
#
# 1 - R2 score: 0.1271514424
# elapsed: 5s
#
# ==============================
# run 60
# max_depth: 17
# max_features: 0.740896321534
# min_samples_leaf: 4
#
# 1 - R2 score: 0.126617167226
# elapsed: 4s
#
# ==============================
# run 61
# max_depth: 25
# max_features: 0.960715682383
# min_samples_leaf: 1
#
# 1 - R2 score: 0.110605587644
# elapsed: 8s
#
# ==============================
# run 62
# max_depth: 27
# max_features: 0.551040332808
# min_samples_leaf: 7
#
# 1 - R2 score: 0.131942341243
# elapsed: 4s
#
# ==============================
# run 63
# max_depth: 24
# max_features: 0.96184161612
# min_samples_leaf: 8
#
# 1 - R2 score: 0.137710592634
# elapsed: 5s
#
# ==============================
# run 64
# max_depth: 29
# max_features: 0.422928518322
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123893373152
# elapsed: 4s
#
# ==============================
# run 65
# max_depth: 23
# max_features: 0.812467174747
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113802103093
# elapsed: 8s
#
# ==============================
# run 66
# max_depth: 26
# max_features: 0.89493127178
# min_samples_leaf: 1
#
# 1 - R2 score: 0.109359381308
# elapsed: 8s
#
# ==============================
# run 67
# max_depth: 26
# max_features: 0.9082688285
# min_samples_leaf: 1
#
# 1 - R2 score: 0.11485488909
# elapsed: 9s
#
# ==============================
# run 68
# max_depth: 27
# max_features: 0.836845401262
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117058236713
# elapsed: 7s
#
# ==============================
# run 69
# max_depth: 29
# max_features: 0.695432776022
# min_samples_leaf: 1
#
# 1 - R2 score: 0.110977929611
# elapsed: 8s
#
# ==============================
# run 70
# max_depth: 25
# max_features: 0.948579437824
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114206694973
# elapsed: 9s
#
# ==============================
# run 71
# max_depth: 21
# max_features: 0.874882443702
# min_samples_leaf: 3
#
# 1 - R2 score: 0.12356847428
# elapsed: 6s
#
# ==============================
# run 72
# max_depth: 22
# max_features: 0.76365987312
# min_samples_leaf: 2
#
# 1 - R2 score: 0.114926145089
# elapsed: 7s
#
# ==============================
# run 73
# max_depth: 26
# max_features: 0.92519266599
# min_samples_leaf: 4
#
# 1 - R2 score: 0.126296302409
# elapsed: 6s
#
# ==============================
# run 74
# max_depth: 23
# max_features: 0.629107865052
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113080373976
# elapsed: 6s
#
# ==============================
# run 75
# max_depth: 24
# max_features: 0.850692977391
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121765292356
# elapsed: 6s
#
# ==============================
# run 76
# max_depth: 25
# max_features: 0.996518653179
# min_samples_leaf: 4
#
# 1 - R2 score: 0.128046314953
# elapsed: 6s
#
# ==============================
# run 77
# max_depth: 29
# max_features: 0.79318730487
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115868414473
# elapsed: 5s
#
# ==============================
# run 78
# max_depth: 27
# max_features: 0.882852039691
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123784195427
# elapsed: 5s
#
# ==============================
# run 79
# max_depth: 28
# max_features: 0.975685011909
# min_samples_leaf: 1
#
# 1 - R2 score: 0.110267521994
# elapsed: 8s
#
# ==============================
# run 80
# max_depth: 29
# max_features: 0.722156128599
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117145988277
# elapsed: 5s
#
# ==============================
# run 81
# max_depth: 26
# max_features: 0.998862047245
# min_samples_leaf: 5
#
# 1 - R2 score: 0.126450174664
# elapsed: 6s
#
# ==============================
# run 82
# max_depth: 28
# max_features: 0.89894962651
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114491479775
# elapsed: 10s
#
# ==============================
# run 83
# max_depth: 28
# max_features: 0.811355509289
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114987385008
# elapsed: 7s
#
# ==============================
# run 84
# max_depth: 20
# max_features: 0.97191946468
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124607497943
# elapsed: 5s
#
# ==============================
# run 85
# max_depth: 28
# max_features: 0.755924781191
# min_samples_leaf: 1
#
# 1 - R2 score: 0.107368223761
# elapsed: 6s
#
# ==============================
# run 86
# max_depth: 23
# max_features: 0.66957456423
# min_samples_leaf: 1
#
# 1 - R2 score: 0.11261639112
# elapsed: 6s
#
# ==============================
# run 87
# max_depth: 26
# max_features: 0.757568800496
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116124253987
# elapsed: 5s
#
# ==============================
# run 88
# max_depth: 18
# max_features: 0.687991196546
# min_samples_leaf: 9
#
# 1 - R2 score: 0.137542647932
# elapsed: 3s
#
# ==============================
# run 89
# max_depth: 22
# max_features: 0.568982624786
# min_samples_leaf: 6
#
# 1 - R2 score: 0.131905691301
# elapsed: 3s
#
# ==============================
# run 90
# max_depth: 21
# max_features: 0.645674532317
# min_samples_leaf: 4
#
# 1 - R2 score: 0.12510085962
# elapsed: 4s
#
# ==============================
# run 91
# max_depth: 27
# max_features: 0.738612948775
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117405284662
# elapsed: 5s
#
# ==============================
# run 92
# max_depth: 20
# max_features: 0.616330472627
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113942494335
# elapsed: 5s
#
# ==============================
# run 93
# max_depth: 29
# max_features: 0.850987492109
# min_samples_leaf: 6
#
# 1 - R2 score: 0.129697700646
# elapsed: 4s
#
# ==============================
# run 94
# max_depth: 24
# max_features: 0.829091603487
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115278046318
# elapsed: 6s
#
# ==============================
# run 95
# max_depth: 28
# max_features: 0.722029947821
# min_samples_leaf: 5
#
# 1 - R2 score: 0.126376383096
# elapsed: 4s
#
# ==============================
# run 96
# max_depth: 27
# max_features: 0.940801909464
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114138089107
# elapsed: 8s
#
# ==============================
# run 97
# max_depth: 25
# max_features: 0.504681537289
# min_samples_leaf: 3
#
# 1 - R2 score: 0.118185205038
# elapsed: 3s
#
# ==============================
# run 98
# max_depth: 26
# max_features: 0.76918563976
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111970616049
# elapsed: 8s
#
# ==============================
# run 99
# max_depth: 21
# max_features: 0.892259371304
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115913638648
# elapsed: 6s
#
# ==============================
# run 100
# max_depth: 29
# max_features: 0.822947733104
# min_samples_leaf: 6
#
# 1 - R2 score: 0.135148833823
# elapsed: 4s
#
# ==============================
# run 101
# max_depth: 23
# max_features: 0.791409466187
# min_samples_leaf: 7
#
# 1 - R2 score: 0.133338661886
# elapsed: 4s
#
# ==============================
# run 102
# max_depth: 23
# max_features: 0.602767988795
# min_samples_leaf: 5
#
# 1 - R2 score: 0.128962727122
# elapsed: 3s
#
# ==============================
# run 103
# max_depth: 26
# max_features: 0.912514816788
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111742704981
# elapsed: 7s
#
# ==============================
# run 104
# max_depth: 24
# max_features: 0.858107658377
# min_samples_leaf: 4
#
# 1 - R2 score: 0.12562313657
# elapsed: 4s
#
# ==============================
# run 105
# max_depth: 20
# max_features: 0.688834977015
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123156618039
# elapsed: 4s
#
# ==============================
# run 106
# max_depth: 9
# max_features: 0.92592498325
# min_samples_leaf: 8
#
# 1 - R2 score: 0.139160326087
# elapsed: 4s
#
# ==============================
# run 107
# max_depth: 18
# max_features: 0.711821631217
# min_samples_leaf: 9
#
# 1 - R2 score: 0.137039998852
# elapsed: 3s
#
# ==============================
# run 108
# max_depth: 19
# max_features: 0.535474242036
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117470149206
# elapsed: 4s
#
# ==============================
# run 109
# max_depth: 15
# max_features: 0.367385904908
# min_samples_leaf: 2
#
# 1 - R2 score: 0.12339068405
# elapsed: 3s
#
# ==============================
# run 110
# max_depth: 25
# max_features: 0.162869428725
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122080554344
# elapsed: 3s
#
# ==============================
# run 111
# max_depth: 22
# max_features: 0.452458519504
# min_samples_leaf: 1
#
# 1 - R2 score: 0.116570438408
# elapsed: 5s
#
# ==============================
# run 112
# max_depth: 21
# max_features: 0.231640012149
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122636332217
# elapsed: 3s
#
# ==============================
# run 113
# max_depth: 29
# max_features: 0.745415304215
# min_samples_leaf: 7
#
# 1 - R2 score: 0.13644613351
# elapsed: 4s
#
# ==============================
# run 114
# max_depth: 16
# max_features: 0.55326922716
# min_samples_leaf: 6
#
# 1 - R2 score: 0.129805808858
# elapsed: 3s
#
# ==============================
# run 115
# max_depth: 24
# max_features: 0.799055358619
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115712779756
# elapsed: 5s
#
# ==============================
# run 116
# max_depth: 13
# max_features: 0.657944685149
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114163413224
# elapsed: 5s
#
# ==============================
# run 117
# max_depth: 27
# max_features: 0.95912402981
# min_samples_leaf: 5
#
# 1 - R2 score: 0.12607411996
# elapsed: 4s
#
# ==============================
# run 118
# max_depth: 29
# max_features: 0.871868664299
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125754654841
# elapsed: 5s
#
# ==============================
# run 119
# max_depth: 27
# max_features: 0.999928514026
# min_samples_leaf: 4
#
# 1 - R2 score: 0.128046314953
# elapsed: 5s
#
# ==============================
# run 120
# max_depth: 20
# max_features: 0.424281164952
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123432354357
# elapsed: 3s
#
# ==============================
# run 121
# max_depth: 25
# max_features: 0.771976374665
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115374059542
# elapsed: 5s
#
# ==============================
# run 122
# max_depth: 17
# max_features: 0.838214789154
# min_samples_leaf: 3
#
# 1 - R2 score: 0.120928991409
# elapsed: 5s
#
# ==============================
# run 123
# max_depth: 28
# max_features: 0.31079326494
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121844205147
# elapsed: 3s
#
# ==============================
# run 124
# max_depth: 26
# max_features: 0.941493909265
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113250239575
# elapsed: 7s
#
# ==============================
# run 125
# max_depth: 22
# max_features: 0.625143670211
# min_samples_leaf: 4
#
# 1 - R2 score: 0.123710879158
# elapsed: 4s
#
# ==============================
# run 126
# max_depth: 23
# max_features: 0.129285123231
# min_samples_leaf: 1
#
# 1 - R2 score: 0.130688034749
# elapsed: 3s
#
# ==============================
# run 127
# max_depth: 6
# max_features: 0.678385230711
# min_samples_leaf: 1
#
# 1 - R2 score: 0.155951683494
# elapsed: 3s
#
# ==============================
# run 128
# max_depth: 16
# max_features: 0.884977037099
# min_samples_leaf: 1
#
# 1 - R2 score: 0.11494153045
# elapsed: 7s
#
# ==============================
# run 129
# max_depth: 27
# max_features: 0.59175980342
# min_samples_leaf: 4
#
# 1 - R2 score: 0.128094772733
# elapsed: 3s
#
# ==============================
# run 130
# max_depth: 8
# max_features: 0.977711104744
# min_samples_leaf: 3
#
# 1 - R2 score: 0.130880203667
# elapsed: 4s
#
# ==============================
# run 131
# max_depth: 28
# max_features: 0.808626446766
# min_samples_leaf: 5
#
# 1 - R2 score: 0.129523535663
# elapsed: 4s
#
# ==============================
# run 132
# max_depth: 29
# max_features: 0.911782863844
# min_samples_leaf: 1
#
# 1 - R2 score: 0.110108032483
# elapsed: 7s
#
# ==============================
# run 133
# max_depth: 24
# max_features: 0.861872938035
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115842925404
# elapsed: 5s
#
# ==============================
# run 134
# max_depth: 14
# max_features: 0.516306389033
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125346368689
# elapsed: 3s
#
# ==============================
# run 135
# max_depth: 22
# max_features: 0.726387576121
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116891350291
# elapsed: 6s
#
# ==============================
# run 136
# max_depth: 25
# max_features: 0.486914359053
# min_samples_leaf: 1
#
# 1 - R2 score: 0.117732741747
# elapsed: 5s
#
# ==============================
# run 137
# max_depth: 11
# max_features: 0.568727265634
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123539667136
# elapsed: 4s
#
# ==============================
# run 138
# max_depth: 19
# max_features: 0.899176549398
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116519307849
# elapsed: 6s
#
# ==============================
# run 139
# max_depth: 26
# max_features: 0.264936148511
# min_samples_leaf: 5
#
# 1 - R2 score: 0.135450966338
# elapsed: 2s
#
# ==============================
# run 140
# max_depth: 29
# max_features: 0.700072381415
# min_samples_leaf: 1
#
# 1 - R2 score: 0.109287098456
# elapsed: 6s
#
# ==============================
# run 141
# max_depth: 29
# max_features: 0.643532645229
# min_samples_leaf: 4
#
# 1 - R2 score: 0.12428896145
# elapsed: 4s
#
# ==============================
# run 142
# max_depth: 28
# max_features: 0.469467921437
# min_samples_leaf: 1
#
# 1 - R2 score: 0.115911162321
# elapsed: 5s
#
# ==============================
# run 143
# max_depth: 5
# max_features: 0.755011988667
# min_samples_leaf: 7
#
# 1 - R2 score: 0.174344881748
# elapsed: 3s
#
# ==============================
# run 144
# max_depth: 27
# max_features: 0.780263722137
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121927949968
# elapsed: 5s
#
# ==============================
# run 145
# max_depth: 27
# max_features: 0.601663387507
# min_samples_leaf: 4
#
# 1 - R2 score: 0.124440723626
# elapsed: 4s
#
# ==============================
# run 146
# max_depth: 29
# max_features: 0.705512230283
# min_samples_leaf: 6
#
# 1 - R2 score: 0.129979480031
# elapsed: 4s
#
# ==============================
# run 147
# max_depth: 29
# max_features: 0.848365045371
# min_samples_leaf: 1
#
# 1 - R2 score: 0.109101680606
# elapsed: 8s
#
# ==============================
# run 148
# max_depth: 29
# max_features: 0.827839361179
# min_samples_leaf: 1
#
# 1 - R2 score: 0.116460164505
# elapsed: 8s
#
# ==============================
# run 149
# max_depth: 28
# max_features: 0.639781586817
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113474578416
# elapsed: 6s
#
# ==============================
# run 150
# max_depth: 27
# max_features: 0.739163928399
# min_samples_leaf: 1
#
# 1 - R2 score: 0.11185609532
# elapsed: 6s
#
# ==============================
# run 151
# max_depth: 25
# max_features: 0.662569799415
# min_samples_leaf: 2
#
# 1 - R2 score: 0.114332381882
# elapsed: 5s
#
# ==============================
# run 152
# max_depth: 29
# max_features: 0.693475875968
# min_samples_leaf: 1
#
# 1 - R2 score: 0.110977929611
# elapsed: 6s
#
# ==============================
# run 153
# max_depth: 28
# max_features: 0.790384674193
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115868414473
# elapsed: 5s
#
# ==============================
# run 154
# max_depth: 29
# max_features: 0.848418303082
# min_samples_leaf: 1
#
# 1 - R2 score: 0.109101680606
# elapsed: 7s
#
# ==============================
# run 155
# max_depth: 29
# max_features: 0.851625033905
# min_samples_leaf: 1
#
# 1 - R2 score: 0.109101680606
# elapsed: 7s
#
# ==============================
# run 156
# max_depth: 29
# max_features: 0.84483828144
# min_samples_leaf: 1
#
# 1 - R2 score: 0.109069150699
# elapsed: 7s
#
# ==============================
# run 157
# max_depth: 25
# max_features: 0.932634364347
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111911916412
# elapsed: 7s
#
# ==============================
# run 158
# max_depth: 28
# max_features: 0.808231561714
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111705301236
# elapsed: 6s
#
# ==============================
# run 159
# max_depth: 29
# max_features: 0.758310054648
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116124253987
# elapsed: 5s
#
# ==============================
# run 160
# max_depth: 27
# max_features: 0.868282946742
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116021666537
# elapsed: 6s
#
# ==============================
# run 161
# max_depth: 26
# max_features: 0.820877200477
# min_samples_leaf: 2
#
# 1 - R2 score: 0.108563802241
# elapsed: 7s
#
# ==============================
# run 162
# max_depth: 24
# max_features: 0.721184544949
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117244766323
# elapsed: 6s
#
# ==============================
# run 163
# max_depth: 28
# max_features: 0.949901121386
# min_samples_leaf: 2
#
# 1 - R2 score: 0.114189189741
# elapsed: 7s
#
# ==============================
# run 164
# max_depth: 23
# max_features: 0.827760142076
# min_samples_leaf: 1
#
# 1 - R2 score: 0.115675435382
# elapsed: 9s
#
# ==============================
# run 165
# max_depth: 26
# max_features: 0.796125514496
# min_samples_leaf: 3
#
# 1 - R2 score: 0.12667378548
# elapsed: 5s
#
# ==============================
# run 166
# max_depth: 25
# max_features: 0.910991334016
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113768211839
# elapsed: 7s
#
# ==============================
# run 167
# max_depth: 26
# max_features: 0.774179210388
# min_samples_leaf: 2
#
# 1 - R2 score: 0.11570873027
# elapsed: 5s
#
# ==============================
# run 168
# max_depth: 28
# max_features: 0.734276896264
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117405284662
# elapsed: 5s
#
# ==============================
# run 169
# max_depth: 23
# max_features: 0.884935029983
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113539746116
# elapsed: 7s
#
# ==============================
# run 170
# max_depth: 22
# max_features: 0.924158832432
# min_samples_leaf: 3
#
# 1 - R2 score: 0.122111595674
# elapsed: 5s
#
# ==============================
# run 171
# max_depth: 26
# max_features: 0.989633065305
# min_samples_leaf: 2
#
# 1 - R2 score: 0.113619803166
# elapsed: 6s
#
# ==============================
# run 172
# max_depth: 21
# max_features: 0.810759744385
# min_samples_leaf: 6
#
# 1 - R2 score: 0.129359150746
# elapsed: 4s
#
# ==============================
# run 173
# max_depth: 28
# max_features: 0.676350241866
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118611892659
# elapsed: 4s
#
# ==============================
# run 174
# max_depth: 24
# max_features: 0.616045232928
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114089120048
# elapsed: 5s
#
# ==============================
# run 175
# max_depth: 27
# max_features: 0.95546125954
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111405138296
# elapsed: 8s
#
# ==============================
# run 176
# max_depth: 29
# max_features: 0.750827634263
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121543027055
# elapsed: 5s
#
# ==============================
# run 177
# max_depth: 20
# max_features: 0.833229999668
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125164409655
# elapsed: 5s
#
# ==============================
# run 178
# max_depth: 26
# max_features: 0.199418476699
# min_samples_leaf: 1
#
# 1 - R2 score: 0.123361346794
# elapsed: 3s
#
# ==============================
# run 179
# max_depth: 7
# max_features: 0.875621604672
# min_samples_leaf: 2
#
# 1 - R2 score: 0.135842129541
# elapsed: 3s
#
# ==============================
# run 180
# max_depth: 29
# max_features: 0.77748681849
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111280313163
# elapsed: 6s
#
# ==============================
# run 181
# max_depth: 24
# max_features: 0.97369229108
# min_samples_leaf: 9
#
# 1 - R2 score: 0.136853500134
# elapsed: 4s
#
# ==============================
# run 182
# max_depth: 27
# max_features: 0.851258222964
# min_samples_leaf: 4
#
# 1 - R2 score: 0.12562313657
# elapsed: 4s
#
# ==============================
# run 183
# max_depth: 25
# max_features: 0.577732078757
# min_samples_leaf: 5
#
# 1 - R2 score: 0.131663446337
# elapsed: 3s
#
# ==============================
# run 184
# max_depth: 28
# max_features: 0.717111378344
# min_samples_leaf: 1
#
# 1 - R2 score: 0.112311673366
# elapsed: 6s
#
# ==============================
# run 185
# max_depth: 23
# max_features: 0.896332647107
# min_samples_leaf: 8
#
# 1 - R2 score: 0.134248413588
# elapsed: 4s
#
# ==============================
# run 186
# max_depth: 14
# max_features: 0.817613865539
# min_samples_leaf: 3
#
# 1 - R2 score: 0.120761811984
# elapsed: 4s
#
# ==============================
# run 187
# max_depth: 25
# max_features: 0.552186602269
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116265617452
# elapsed: 4s
#
# ==============================
# run 188
# max_depth: 21
# max_features: 0.647949271433
# min_samples_leaf: 2
#
# 1 - R2 score: 0.113981918063
# elapsed: 4s
#
# ==============================
# run 189
# max_depth: 16
# max_features: 0.931947515213
# min_samples_leaf: 2
#
# 1 - R2 score: 0.114176672982
# elapsed: 5s
#
# ==============================
# run 190
# max_depth: 12
# max_features: 0.76246862124
# min_samples_leaf: 9
#
# 1 - R2 score: 0.133481075913
# elapsed: 3s
#
# ==============================
# run 191
# max_depth: 7
# max_features: 0.797416326496
# min_samples_leaf: 1
#
# 1 - R2 score: 0.137673354521
# elapsed: 3s
#
# ==============================
# run 192
# max_depth: 18
# max_features: 0.42721270953
# min_samples_leaf: 1
#
# 1 - R2 score: 0.115284724994
# elapsed: 4s
#
# ==============================
# run 193
# max_depth: 29
# max_features: 0.687050612911
# min_samples_leaf: 1
#
# 1 - R2 score: 0.110977929611
# elapsed: 6s
#
# ==============================
# run 194
# max_depth: 10
# max_features: 0.842556566727
# min_samples_leaf: 5
#
# 1 - R2 score: 0.127925614635
# elapsed: 4s
#
# ==============================
# run 195
# max_depth: 5
# max_features: 0.996406735609
# min_samples_leaf: 3
#
# 1 - R2 score: 0.169868943019
# elapsed: 3s
#
# ==============================
# run 196
# max_depth: 27
# max_features: 0.872701245826
# min_samples_leaf: 9
#
# 1 - R2 score: 0.139466876416
# elapsed: 4s
#
# ==============================
# run 197
# max_depth: 19
# max_features: 0.703324829857
# min_samples_leaf: 5
#
# 1 - R2 score: 0.129520020255
# elapsed: 4s
#
# ==============================
# run 198
# max_depth: 28
# max_features: 0.664126790909
# min_samples_leaf: 1
#
# 1 - R2 score: 0.11000229931
# elapsed: 6s
#
# ==============================
# run 199
# max_depth: 27
# max_features: 0.739096036449
# min_samples_leaf: 7
#
# 1 - R2 score: 0.13644613351
# elapsed: 3s
#
# ==============================
# run 200
# max_depth: 23
# max_features: 0.908203171784
# min_samples_leaf: 3
#
# 1 - R2 score: 0.122357538132
# elapsed: 5s
#
# Seconds passed: 980
# {'max_features': 0.7559247811910019, 'max_depth': 28.87116907331449, 'min_samples_leaf': 1.004234495880342}
