# %%
import pandas as pd
import numpy as np
import hyperopt
import os
import sys
import csv

from time import time

from hyperopt import hp, fmin, tpe
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Loading data

# %%
df = pd.read_csv('data/manipulated_train.csv')

# %%
X = df.drop(['SalePrice'], axis=1)
y = df['SalePrice']

# %%
X.shape
# Out:
# (1460, 79)

# %% [markdown]
# ### Setting paratemers

# %%
# Test parameters
max_evals = 200
run_counter = 0
num_cv = 10
n_jobs = -1
output_log_file = '~/temp/hyperopt-rf.csv'

# %%
rf = RandomForestRegressor()
rf.get_params()
# Out:
# {'bootstrap': True,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_split': 1e-07,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 10,
#  'n_jobs': 1,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Hyperparameters space
space = (
    hp.uniform('max_depth', 5, 30),
    hp.uniform('max_features', 0.1, 1),
    hp.uniform('min_samples_leaf', 1, 10)
)

# %% [markdown]
# ### Function run_wrapper
#
# Just a function for counting and logging experiments, that is called by the hyperopt.fmin(). It also calls the run_test(), the function that indeed execute the experiment for the input parameters.

# %%
def run_wrapper(params):
    global run_counter
    global o_f
    
    run_counter += 1
    print "=============================="
    print "run", run_counter
    
    s = time()
    r2score = run_test(params)
    
    print
    print "1 - R2 score:", r2score
    print "elapsed: {}s \n".format(int(round(time() - s)))
    
    writer.writerow([r2score] + list(params))
    o_f.flush()
    return r2score

# %% [markdown]
# ### Function run_test
#
# The function that receives the parameters, execute the test and return the results. I am using a cross-validation for obtaining the score, and returning it for being optmized by hyperopt.fmin() (therefore I subtracted 1 - score).

# %%
def run_test(params):
    max_depth, max_features, min_samples_leaf = params
    max_depth = int(max_depth)
    min_samples_leaf = int(min_samples_leaf)
    
    print "max_depth:", max_depth
    print "max_features:", max_features
    print "min_samples_leaf:", min_samples_leaf
    
    rf = RandomForestRegressor(max_depth=max_depth,
                               max_features=max_features,
                               min_samples_leaf=min_samples_leaf,
                               n_estimators=100,
                               random_state=66)
    
    cvs = cross_val_score(rf, X, y,
                          cv=num_cv,
                          n_jobs=n_jobs)
    
    return 1 - np.median(cvs)

# %% [markdown]
# ### Main function
#
# Just some logging and calling the hyperopt.fmin(). In the end, it obtains the best parameters -- the ones that minimizes the objective function.

# %%
if __name__ == '__main__':
    
    headers = 'r2score max_depth max_features min_samples_leaf'.split()
    o_f = open(output_log_file, 'wb')
    writer = csv.writer(o_f)
    writer.writerow(headers)
    
    start_time = time()
    best = fmin(run_wrapper, space, algo=tpe.suggest, max_evals=max_evals)
    end_time = time()
    
    print "Seconds passed:", int(round(end_time - start_time))
    print best
# Out:
# ==============================
# run 1
# max_depth: 24
# max_features: 0.418889401207
# min_samples_leaf: 6
#
# 1 - R2 score: 0.129809790362
# elapsed: 3s
#
# ==============================
# run 2
# max_depth: 24
# max_features: 0.586025559233
# min_samples_leaf: 7
#
# 1 - R2 score: 0.135570006944
# elapsed: 4s
#
# ==============================
# run 3
# max_depth: 15
# max_features: 0.210280948663
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121147310145
# elapsed: 3s
#
# ==============================
# run 4
# max_depth: 19
# max_features: 0.743592498961
# min_samples_leaf: 7
#
# 1 - R2 score: 0.134676940817
# elapsed: 5s
#
# ==============================
# run 5
# max_depth: 17
# max_features: 0.845761184623
# min_samples_leaf: 9
#
# 1 - R2 score: 0.14289802093
# elapsed: 5s
#
# ==============================
# run 6
# max_depth: 24
# max_features: 0.871989360456
# min_samples_leaf: 8
#
# 1 - R2 score: 0.136744075397
# elapsed: 5s
#
# ==============================
# run 7
# max_depth: 10
# max_features: 0.615685349863
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121957851187
# elapsed: 5s
#
# ==============================
# run 8
# max_depth: 21
# max_features: 0.791817278334
# min_samples_leaf: 8
#
# 1 - R2 score: 0.140351352994
# elapsed: 5s
#
# ==============================
# run 9
# max_depth: 21
# max_features: 0.970847415779
# min_samples_leaf: 7
#
# 1 - R2 score: 0.139485084353
# elapsed: 6s
#
# ==============================
# run 10
# max_depth: 16
# max_features: 0.973016333458
# min_samples_leaf: 4
#
# 1 - R2 score: 0.131758314673
# elapsed: 6s
#
# ==============================
# run 11
# max_depth: 25
# max_features: 0.555067197277
# min_samples_leaf: 7
#
# 1 - R2 score: 0.135841669862
# elapsed: 4s
#
# ==============================
# run 12
# max_depth: 29
# max_features: 0.369711012191
# min_samples_leaf: 9
#
# 1 - R2 score: 0.139631755173
# elapsed: 3s
#
# ==============================
# run 13
# max_depth: 8
# max_features: 0.794217537139
# min_samples_leaf: 3
#
# 1 - R2 score: 0.130969253057
# elapsed: 6s
#
# ==============================
# run 14
# max_depth: 15
# max_features: 0.817614497347
# min_samples_leaf: 5
#
# 1 - R2 score: 0.131295767268
# elapsed: 6s
#
# ==============================
# run 15
# max_depth: 5
# max_features: 0.56377802136
# min_samples_leaf: 2
#
# 1 - R2 score: 0.157096739719
# elapsed: 4s
#
# ==============================
# run 16
# max_depth: 19
# max_features: 0.17228314008
# min_samples_leaf: 5
#
# 1 - R2 score: 0.132923581813
# elapsed: 3s
#
# ==============================
# run 17
# max_depth: 14
# max_features: 0.458107089661
# min_samples_leaf: 9
#
# 1 - R2 score: 0.138296248894
# elapsed: 4s
#
# ==============================
# run 18
# max_depth: 6
# max_features: 0.347067056077
# min_samples_leaf: 9
#
# 1 - R2 score: 0.145113500512
# elapsed: 3s
#
# ==============================
# run 19
# max_depth: 18
# max_features: 0.722528271356
# min_samples_leaf: 9
#
# 1 - R2 score: 0.140317376792
# elapsed: 4s
#
# ==============================
# run 20
# max_depth: 17
# max_features: 0.481338050104
# min_samples_leaf: 5
#
# 1 - R2 score: 0.126264928443
# elapsed: 4s
#
# ==============================
# run 21
# max_depth: 11
# max_features: 0.112778608191
# min_samples_leaf: 1
#
# 1 - R2 score: 0.127524294918
# elapsed: 2s
#
# ==============================
# run 22
# max_depth: 12
# max_features: 0.238493339232
# min_samples_leaf: 1
#
# 1 - R2 score: 0.123216667046
# elapsed: 3s
#
# ==============================
# run 23
# max_depth: 10
# max_features: 0.665253954154
# min_samples_leaf: 2
#
# 1 - R2 score: 0.126517850633
# elapsed: 5s
#
# ==============================
# run 24
# max_depth: 13
# max_features: 0.259752775038
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122701545274
# elapsed: 3s
#
# ==============================
# run 25
# max_depth: 8
# max_features: 0.641372927686
# min_samples_leaf: 3
#
# 1 - R2 score: 0.131055450449
# elapsed: 4s
#
# ==============================
# run 26
# max_depth: 8
# max_features: 0.325281728546
# min_samples_leaf: 3
#
# 1 - R2 score: 0.131821248421
# elapsed: 3s
#
# ==============================
# run 27
# max_depth: 14
# max_features: 0.494087031338
# min_samples_leaf: 4
#
# 1 - R2 score: 0.127354104756
# elapsed: 4s
#
# ==============================
# run 28
# max_depth: 6
# max_features: 0.661552272315
# min_samples_leaf: 1
#
# 1 - R2 score: 0.146272029344
# elapsed: 4s
#
# ==============================
# run 29
# max_depth: 28
# max_features: 0.113338195512
# min_samples_leaf: 5
#
# 1 - R2 score: 0.138806390197
# elapsed: 2s
#
# ==============================
# run 30
# max_depth: 10
# max_features: 0.414243829121
# min_samples_leaf: 4
#
# 1 - R2 score: 0.12370464405
# elapsed: 4s
#
# ==============================
# run 31
# max_depth: 22
# max_features: 0.254165437486
# min_samples_leaf: 6
#
# 1 - R2 score: 0.129507827689
# elapsed: 3s
#
# ==============================
# run 32
# max_depth: 13
# max_features: 0.616694417488
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122354128506
# elapsed: 6s
#
# ==============================
# run 33
# max_depth: 26
# max_features: 0.714513916909
# min_samples_leaf: 3
#
# 1 - R2 score: 0.130311273492
# elapsed: 5s
#
# ==============================
# run 34
# max_depth: 17
# max_features: 0.179569696102
# min_samples_leaf: 2
#
# 1 - R2 score: 0.124445511612
# elapsed: 3s
#
# ==============================
# run 35
# max_depth: 10
# max_features: 0.896252000522
# min_samples_leaf: 3
#
# 1 - R2 score: 0.126559461772
# elapsed: 6s
#
# ==============================
# run 36
# max_depth: 7
# max_features: 0.50823207291
# min_samples_leaf: 6
#
# 1 - R2 score: 0.133625053093
# elapsed: 3s
#
# ==============================
# run 37
# max_depth: 20
# max_features: 0.916667515713
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122780442187
# elapsed: 9s
#
# ==============================
# run 38
# max_depth: 23
# max_features: 0.41095703167
# min_samples_leaf: 4
#
# 1 - R2 score: 0.124783358054
# elapsed: 4s
#
# ==============================
# run 39
# max_depth: 18
# max_features: 0.527620068711
# min_samples_leaf: 8
#
# 1 - R2 score: 0.135567383177
# elapsed: 4s
#
# ==============================
# run 40
# max_depth: 16
# max_features: 0.291972619759
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122164961254
# elapsed: 4s
#
# ==============================
# run 41
# max_depth: 12
# max_features: 0.581161135227
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123457347477
# elapsed: 5s
#
# ==============================
# run 42
# max_depth: 14
# max_features: 0.999042032877
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12624989648
# elapsed: 8s
#
# ==============================
# run 43
# max_depth: 22
# max_features: 0.767440154922
# min_samples_leaf: 2
#
# 1 - R2 score: 0.119659979479
# elapsed: 6s
#
# ==============================
# run 44
# max_depth: 27
# max_features: 0.757207877147
# min_samples_leaf: 4
#
# 1 - R2 score: 0.1303583481
# elapsed: 5s
#
# ==============================
# run 45
# max_depth: 22
# max_features: 0.857823421761
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122026355808
# elapsed: 7s
#
# ==============================
# run 46
# max_depth: 24
# max_features: 0.934742728342
# min_samples_leaf: 6
#
# 1 - R2 score: 0.136939525905
# elapsed: 6s
#
# ==============================
# run 47
# max_depth: 29
# max_features: 0.831675989564
# min_samples_leaf: 7
#
# 1 - R2 score: 0.139246214298
# elapsed: 6s
#
# ==============================
# run 48
# max_depth: 23
# max_features: 0.777270936279
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125452446826
# elapsed: 7s
#
# ==============================
# run 49
# max_depth: 20
# max_features: 0.698627101757
# min_samples_leaf: 4
#
# 1 - R2 score: 0.129498743445
# elapsed: 6s
#
# ==============================
# run 50
# max_depth: 19
# max_features: 0.194417162143
# min_samples_leaf: 4
#
# 1 - R2 score: 0.128132662238
# elapsed: 2s
#
# ==============================
# run 51
# max_depth: 26
# max_features: 0.453207636542
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121825868228
# elapsed: 5s
#
# ==============================
# run 52
# max_depth: 28
# max_features: 0.595382975111
# min_samples_leaf: 7
#
# 1 - R2 score: 0.134228753061
# elapsed: 4s
#
# ==============================
# run 53
# max_depth: 16
# max_features: 0.386121611258
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120964190762
# elapsed: 4s
#
# ==============================
# run 54
# max_depth: 16
# max_features: 0.367213404695
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123759994011
# elapsed: 4s
#
# ==============================
# run 55
# max_depth: 18
# max_features: 0.535924819108
# min_samples_leaf: 1
#
# 1 - R2 score: 0.124351071316
# elapsed: 6s
#
# ==============================
# run 56
# max_depth: 27
# max_features: 0.140192088228
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12369557423
# elapsed: 3s
#
# ==============================
# run 57
# max_depth: 21
# max_features: 0.453296641271
# min_samples_leaf: 5
#
# 1 - R2 score: 0.127620041052
# elapsed: 3s
#
# ==============================
# run 58
# max_depth: 15
# max_features: 0.311122379603
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124956303004
# elapsed: 3s
#
# ==============================
# run 59
# max_depth: 24
# max_features: 0.814284456367
# min_samples_leaf: 8
#
# 1 - R2 score: 0.13900339353
# elapsed: 5s
#
# ==============================
# run 60
# max_depth: 25
# max_features: 0.683686772035
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123587408816
# elapsed: 6s
#
# ==============================
# run 61
# max_depth: 19
# max_features: 0.385254839129
# min_samples_leaf: 2
#
# 1 - R2 score: 0.119089582426
# elapsed: 4s
#
# ==============================
# run 62
# max_depth: 22
# max_features: 0.751432202235
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123653000921
# elapsed: 7s
#
# ==============================
# run 63
# max_depth: 20
# max_features: 0.956703096969
# min_samples_leaf: 1
#
# 1 - R2 score: 0.125091959318
# elapsed: 9s
#
# ==============================
# run 64
# max_depth: 19
# max_features: 0.231422635961
# min_samples_leaf: 9
#
# 1 - R2 score: 0.139869299169
# elapsed: 2s
#
# ==============================
# run 65
# max_depth: 25
# max_features: 0.872862697656
# min_samples_leaf: 4
#
# 1 - R2 score: 0.129447038006
# elapsed: 6s
#
# ==============================
# run 66
# max_depth: 17
# max_features: 0.392876151524
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122012977468
# elapsed: 4s
#
# ==============================
# run 67
# max_depth: 13
# max_features: 0.295147043778
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122005700307
# elapsed: 3s
#
# ==============================
# run 68
# max_depth: 19
# max_features: 0.353237488788
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121241819528
# elapsed: 4s
#
# ==============================
# run 69
# max_depth: 18
# max_features: 0.436493176525
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122708782878
# elapsed: 5s
#
# ==============================
# run 70
# max_depth: 16
# max_features: 0.477552512965
# min_samples_leaf: 1
#
# 1 - R2 score: 0.121034296678
# elapsed: 6s
#
# ==============================
# run 71
# max_depth: 15
# max_features: 0.39170609206
# min_samples_leaf: 1
#
# 1 - R2 score: 0.117956922892
# elapsed: 5s
#
# ==============================
# run 72
# max_depth: 21
# max_features: 0.502087386764
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122730555803
# elapsed: 6s
#
# ==============================
# run 73
# max_depth: 9
# max_features: 0.620719232641
# min_samples_leaf: 3
#
# 1 - R2 score: 0.127774255366
# elapsed: 4s
#
# ==============================
# run 74
# max_depth: 12
# max_features: 0.333519776718
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120389385849
# elapsed: 4s
#
# ==============================
# run 75
# max_depth: 15
# max_features: 0.562291420684
# min_samples_leaf: 4
#
# 1 - R2 score: 0.127018094541
# elapsed: 4s
#
# ==============================
# run 76
# max_depth: 17
# max_features: 0.221030947549
# min_samples_leaf: 1
#
# 1 - R2 score: 0.123126991414
# elapsed: 4s
#
# ==============================
# run 77
# max_depth: 14
# max_features: 0.254523346684
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122238169308
# elapsed: 3s
#
# ==============================
# run 78
# max_depth: 23
# max_features: 0.282763050284
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124251305036
# elapsed: 3s
#
# ==============================
# run 79
# max_depth: 11
# max_features: 0.640432094705
# min_samples_leaf: 5
#
# 1 - R2 score: 0.128325969581
# elapsed: 4s
#
# ==============================
# run 80
# max_depth: 22
# max_features: 0.426140786776
# min_samples_leaf: 4
#
# 1 - R2 score: 0.125466918682
# elapsed: 4s
#
# ==============================
# run 81
# max_depth: 20
# max_features: 0.474209920443
# min_samples_leaf: 5
#
# 1 - R2 score: 0.128983119721
# elapsed: 4s
#
# ==============================
# run 82
# max_depth: 11
# max_features: 0.163879948639
# min_samples_leaf: 1
#
# 1 - R2 score: 0.126285403028
# elapsed: 3s
#
# ==============================
# run 83
# max_depth: 23
# max_features: 0.527645234864
# min_samples_leaf: 6
#
# 1 - R2 score: 0.132145968673
# elapsed: 4s
#
# ==============================
# run 84
# max_depth: 18
# max_features: 0.38761406855
# min_samples_leaf: 3
#
# 1 - R2 score: 0.122178302528
# elapsed: 4s
#
# ==============================
# run 85
# max_depth: 15
# max_features: 0.596024556257
# min_samples_leaf: 1
#
# 1 - R2 score: 0.126796380277
# elapsed: 6s
#
# ==============================
# run 86
# max_depth: 14
# max_features: 0.576204635215
# min_samples_leaf: 1
#
# 1 - R2 score: 0.124454580162
# elapsed: 6s
#
# ==============================
# run 87
# max_depth: 7
# max_features: 0.99760128102
# min_samples_leaf: 2
#
# 1 - R2 score: 0.139173354427
# elapsed: 5s
#
# ==============================
# run 88
# max_depth: 26
# max_features: 0.717262013666
# min_samples_leaf: 2
#
# 1 - R2 score: 0.125487822223
# elapsed: 6s
#
# ==============================
# run 89
# max_depth: 27
# max_features: 0.277360925173
# min_samples_leaf: 4
#
# 1 - R2 score: 0.129934097372
# elapsed: 3s
#
# ==============================
# run 90
# max_depth: 13
# max_features: 0.329016857751
# min_samples_leaf: 1
#
# 1 - R2 score: 0.119164090714
# elapsed: 4s
#
# ==============================
# run 91
# max_depth: 9
# max_features: 0.208061566506
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122440178739
# elapsed: 3s
#
# ==============================
# run 92
# max_depth: 13
# max_features: 0.34446382136
# min_samples_leaf: 1
#
# 1 - R2 score: 0.120906546095
# elapsed: 4s
#
# ==============================
# run 93
# max_depth: 12
# max_features: 0.1155235403
# min_samples_leaf: 9
#
# 1 - R2 score: 0.148577393128
# elapsed: 2s
#
# ==============================
# run 94
# max_depth: 9
# max_features: 0.3097677585
# min_samples_leaf: 1
#
# 1 - R2 score: 0.125812911166
# elapsed: 3s
#
# ==============================
# run 95
# max_depth: 16
# max_features: 0.138133749727
# min_samples_leaf: 8
#
# 1 - R2 score: 0.144562098196
# elapsed: 2s
#
# ==============================
# run 96
# max_depth: 5
# max_features: 0.405090701983
# min_samples_leaf: 3
#
# 1 - R2 score: 0.156300804071
# elapsed: 3s
#
# ==============================
# run 97
# max_depth: 8
# max_features: 0.361242197308
# min_samples_leaf: 1
#
# 1 - R2 score: 0.128771160683
# elapsed: 3s
#
# ==============================
# run 98
# max_depth: 14
# max_features: 0.541842566495
# min_samples_leaf: 2
#
# 1 - R2 score: 0.124309043581
# elapsed: 5s
#
# ==============================
# run 99
# max_depth: 11
# max_features: 0.268331706687
# min_samples_leaf: 3
#
# 1 - R2 score: 0.127139537848
# elapsed: 4s
#
# ==============================
# run 100
# max_depth: 13
# max_features: 0.437677018987
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118407056104
# elapsed: 5s
#
# ==============================
# run 101
# max_depth: 11
# max_features: 0.438730096228
# min_samples_leaf: 7
#
# 1 - R2 score: 0.131758158198
# elapsed: 4s
#
# ==============================
# run 102
# max_depth: 16
# max_features: 0.489448889847
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125889118217
# elapsed: 4s
#
# ==============================
# run 103
# max_depth: 17
# max_features: 0.511398044034
# min_samples_leaf: 2
#
# 1 - R2 score: 0.124122364295
# elapsed: 5s
#
# ==============================
# run 104
# max_depth: 12
# max_features: 0.463653476819
# min_samples_leaf: 5
#
# 1 - R2 score: 0.126811131359
# elapsed: 5s
#
# ==============================
# run 105
# max_depth: 20
# max_features: 0.308031213564
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125127338012
# elapsed: 4s
#
# ==============================
# run 106
# max_depth: 9
# max_features: 0.376720612223
# min_samples_leaf: 4
#
# 1 - R2 score: 0.128061255928
# elapsed: 4s
#
# ==============================
# run 107
# max_depth: 15
# max_features: 0.238727034531
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122841153439
# elapsed: 4s
#
# ==============================
# run 108
# max_depth: 19
# max_features: 0.41302584177
# min_samples_leaf: 6
#
# 1 - R2 score: 0.126708245353
# elapsed: 5s
#
# ==============================
# run 109
# max_depth: 13
# max_features: 0.439976943076
# min_samples_leaf: 4
#
# 1 - R2 score: 0.124316984676
# elapsed: 4s
#
# ==============================
# run 110
# max_depth: 18
# max_features: 0.66107214776
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12138802154
# elapsed: 8s
#
# ==============================
# run 111
# max_depth: 22
# max_features: 0.517242250323
# min_samples_leaf: 4
#
# 1 - R2 score: 0.127551340371
# elapsed: 4s
#
# ==============================
# run 112
# max_depth: 17
# max_features: 0.558523978123
# min_samples_leaf: 5
#
# 1 - R2 score: 0.128910018782
# elapsed: 4s
#
# ==============================
# run 113
# max_depth: 18
# max_features: 0.185532992558
# min_samples_leaf: 2
#
# 1 - R2 score: 0.126515323976
# elapsed: 3s
#
# ==============================
# run 114
# max_depth: 20
# max_features: 0.605994443784
# min_samples_leaf: 5
#
# 1 - R2 score: 0.129366094933
# elapsed: 4s
#
# ==============================
# run 115
# max_depth: 8
# max_features: 0.167755941308
# min_samples_leaf: 7
#
# 1 - R2 score: 0.137448225375
# elapsed: 2s
#
# ==============================
# run 116
# max_depth: 14
# max_features: 0.401727762258
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121181653198
# elapsed: 4s
#
# ==============================
# run 117
# max_depth: 16
# max_features: 0.373828396648
# min_samples_leaf: 1
#
# 1 - R2 score: 0.120464297156
# elapsed: 5s
#
# ==============================
# run 118
# max_depth: 10
# max_features: 0.689520681839
# min_samples_leaf: 6
#
# 1 - R2 score: 0.132920533736
# elapsed: 5s
#
# ==============================
# run 119
# max_depth: 14
# max_features: 0.347450374663
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123226768036
# elapsed: 4s
#
# ==============================
# run 120
# max_depth: 6
# max_features: 0.245852463896
# min_samples_leaf: 4
#
# 1 - R2 score: 0.143636515683
# elapsed: 3s
#
# ==============================
# run 121
# max_depth: 16
# max_features: 0.491340884114
# min_samples_leaf: 5
#
# 1 - R2 score: 0.126281009195
# elapsed: 4s
#
# ==============================
# run 122
# max_depth: 11
# max_features: 0.205479662502
# min_samples_leaf: 3
#
# 1 - R2 score: 0.122357369999
# elapsed: 3s
#
# ==============================
# run 123
# max_depth: 12
# max_features: 0.7339721571
# min_samples_leaf: 1
#
# 1 - R2 score: 0.125201840573
# elapsed: 7s
#
# ==============================
# run 124
# max_depth: 24
# max_features: 0.578299621328
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125324493922
# elapsed: 4307s
#
# ==============================
# run 125
# max_depth: 7
# max_features: 0.634895636219
# min_samples_leaf: 4
#
# 1 - R2 score: 0.134822105602
# elapsed: 4s
#
# ==============================
# run 126
# max_depth: 20
# max_features: 0.322680588043
# min_samples_leaf: 2
#
# 1 - R2 score: 0.119555784615
# elapsed: 4s
#
# ==============================
# run 127
# max_depth: 18
# max_features: 0.423726461678
# min_samples_leaf: 3
#
# 1 - R2 score: 0.12456984892
# elapsed: 4s
#
# ==============================
# run 128
# max_depth: 21
# max_features: 0.471004151142
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125196197204
# elapsed: 4s
#
# ==============================
# run 129
# max_depth: 7
# max_features: 0.14953718978
# min_samples_leaf: 9
#
# 1 - R2 score: 0.145732635851
# elapsed: 2s
#
# ==============================
# run 130
# max_depth: 8
# max_features: 0.298537651067
# min_samples_leaf: 1
#
# 1 - R2 score: 0.132086197018
# elapsed: 3s
#
# ==============================
# run 131
# max_depth: 17
# max_features: 0.223980488666
# min_samples_leaf: 1
#
# 1 - R2 score: 0.123126991414
# elapsed: 4s
#
# ==============================
# run 132
# max_depth: 19
# max_features: 0.104783583181
# min_samples_leaf: 2
#
# 1 - R2 score: 0.127415253
# elapsed: 3s
#
# ==============================
# run 133
# max_depth: 23
# max_features: 0.453168967016
# min_samples_leaf: 1
#
# 1 - R2 score: 0.120797073885
# elapsed: 5s
#
# ==============================
# run 134
# max_depth: 13
# max_features: 0.545731120926
# min_samples_leaf: 2
#
# 1 - R2 score: 0.125439553577
# elapsed: 5s
#
# ==============================
# run 135
# max_depth: 15
# max_features: 0.260583696862
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121414586335
# elapsed: 3s
#
# ==============================
# run 136
# max_depth: 5
# max_features: 0.525578848402
# min_samples_leaf: 3
#
# 1 - R2 score: 0.156622174003
# elapsed: 3s
#
# ==============================
# run 137
# max_depth: 25
# max_features: 0.283285472893
# min_samples_leaf: 6
#
# 1 - R2 score: 0.132081701951
# elapsed: 3s
#
# ==============================
# run 138
# max_depth: 9
# max_features: 0.800148025128
# min_samples_leaf: 1
#
# 1 - R2 score: 0.128307684685
# elapsed: 6s
#
# ==============================
# run 139
# max_depth: 11
# max_features: 0.671054545645
# min_samples_leaf: 1
#
# 1 - R2 score: 0.126950878185
# elapsed: 6s
#
# ==============================
# run 140
# max_depth: 14
# max_features: 0.362777453009
# min_samples_leaf: 4
#
# 1 - R2 score: 0.125772786619
# elapsed: 4s
#
# ==============================
# run 141
# max_depth: 12
# max_features: 0.333585908782
# min_samples_leaf: 3
#
# 1 - R2 score: 0.128885658143
# elapsed: 3s
#
# ==============================
# run 142
# max_depth: 17
# max_features: 0.383322323484
# min_samples_leaf: 1
#
# 1 - R2 score: 0.118673182513
# elapsed: 5s
#
# ==============================
# run 143
# max_depth: 16
# max_features: 0.422903642071
# min_samples_leaf: 1
#
# 1 - R2 score: 0.120563163579
# elapsed: 5s
#
# ==============================
# run 144
# max_depth: 10
# max_features: 0.446636107492
# min_samples_leaf: 8
#
# 1 - R2 score: 0.13241504558
# elapsed: 3s
#
# ==============================
# run 145
# max_depth: 17
# max_features: 0.194980348208
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121433449441
# elapsed: 3s
#
# ==============================
# run 146
# max_depth: 15
# max_features: 0.391911505551
# min_samples_leaf: 1
#
# 1 - R2 score: 0.117956922892
# elapsed: 4s
#
# ==============================
# run 147
# max_depth: 14
# max_features: 0.395974622958
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122563489333
# elapsed: 5s
#
# ==============================
# run 148
# max_depth: 16
# max_features: 0.506940287871
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122584491173
# elapsed: 6s
#
# ==============================
# run 149
# max_depth: 15
# max_features: 0.313741837528
# min_samples_leaf: 1
#
# 1 - R2 score: 0.125452096461
# elapsed: 4s
#
# ==============================
# run 150
# max_depth: 10
# max_features: 0.476655715115
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122654681475
# elapsed: 5s
#
# ==============================
# run 151
# max_depth: 12
# max_features: 0.34987549436
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116660413799
# elapsed: 4s
#
# ==============================
# run 152
# max_depth: 12
# max_features: 0.348048055561
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116660413799
# elapsed: 4s
#
# ==============================
# run 153
# max_depth: 12
# max_features: 0.339364620907
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122990522212
# elapsed: 4s
#
# ==============================
# run 154
# max_depth: 10
# max_features: 0.271445751964
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120055238909
# elapsed: 3s
#
# ==============================
# run 155
# max_depth: 12
# max_features: 0.359473667831
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125822170694
# elapsed: 3s
#
# ==============================
# run 156
# max_depth: 6
# max_features: 0.128803429589
# min_samples_leaf: 2
#
# 1 - R2 score: 0.155697654165
# elapsed: 2s
#
# ==============================
# run 157
# max_depth: 11
# max_features: 0.298122033846
# min_samples_leaf: 2
#
# 1 - R2 score: 0.124433221005
# elapsed: 3s
#
# ==============================
# run 158
# max_depth: 14
# max_features: 0.222750126231
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120188336855
# elapsed: 3s
#
# ==============================
# run 159
# max_depth: 9
# max_features: 0.160297956501
# min_samples_leaf: 2
#
# 1 - R2 score: 0.125852781035
# elapsed: 2s
#
# ==============================
# run 160
# max_depth: 11
# max_features: 0.411244215318
# min_samples_leaf: 7
#
# 1 - R2 score: 0.132552918701
# elapsed: 3s
#
# ==============================
# run 161
# max_depth: 13
# max_features: 0.257829398488
# min_samples_leaf: 1
#
# 1 - R2 score: 0.119364425223
# elapsed: 3s
#
# ==============================
# run 162
# max_depth: 13
# max_features: 0.369798502893
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12335167595
# elapsed: 4s
#
# ==============================
# run 163
# max_depth: 10
# max_features: 0.322982485534
# min_samples_leaf: 3
#
# 1 - R2 score: 0.122827003998
# elapsed: 3s
#
# ==============================
# run 164
# max_depth: 5
# max_features: 0.244398775049
# min_samples_leaf: 1
#
# 1 - R2 score: 0.160777237004
# elapsed: 2s
#
# ==============================
# run 165
# max_depth: 6
# max_features: 0.491182611554
# min_samples_leaf: 2
#
# 1 - R2 score: 0.142531557634
# elapsed: 3s
#
# ==============================
# run 166
# max_depth: 15
# max_features: 0.457964521882
# min_samples_leaf: 4
#
# 1 - R2 score: 0.125035773268
# elapsed: 4s
#
# ==============================
# run 167
# max_depth: 7
# max_features: 0.344660168009
# min_samples_leaf: 3
#
# 1 - R2 score: 0.132606346888
# elapsed: 3s
#
# ==============================
# run 168
# max_depth: 12
# max_features: 0.564666048366
# min_samples_leaf: 4
#
# 1 - R2 score: 0.126911204412
# elapsed: 5s
#
# ==============================
# run 169
# max_depth: 8
# max_features: 0.283881259227
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12941293389
# elapsed: 3s
#
# ==============================
# run 170
# max_depth: 9
# max_features: 0.180207040461
# min_samples_leaf: 1
#
# 1 - R2 score: 0.128168576344
# elapsed: 3s
#
# ==============================
# run 171
# max_depth: 10
# max_features: 0.395191684409
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123211084446
# elapsed: 4s
#
# ==============================
# run 172
# max_depth: 14
# max_features: 0.429016165566
# min_samples_leaf: 5
#
# 1 - R2 score: 0.124522173422
# elapsed: 4s
#
# ==============================
# run 173
# max_depth: 12
# max_features: 0.535106152241
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123328123689
# elapsed: 5s
#
# ==============================
# run 174
# max_depth: 16
# max_features: 0.625544459482
# min_samples_leaf: 1
#
# 1 - R2 score: 0.123990334365
# elapsed: 6s
#
# ==============================
# run 175
# max_depth: 14
# max_features: 0.298671291119
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12007702031
# elapsed: 4s
#
# ==============================
# run 176
# max_depth: 18
# max_features: 0.200305555535
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125630475893
# elapsed: 3s
#
# ==============================
# run 177
# max_depth: 15
# max_features: 0.468990592197
# min_samples_leaf: 1
#
# 1 - R2 score: 0.121496471667
# elapsed: 5s
#
# ==============================
# run 178
# max_depth: 16
# max_features: 0.231396410356
# min_samples_leaf: 3
#
# 1 - R2 score: 0.12339658678
# elapsed: 3s
#
# ==============================
# run 179
# max_depth: 8
# max_features: 0.595544289692
# min_samples_leaf: 2
#
# 1 - R2 score: 0.128869469907
# elapsed: 4s
#
# ==============================
# run 180
# max_depth: 11
# max_features: 0.350776365812
# min_samples_leaf: 5
#
# 1 - R2 score: 0.127033483095
# elapsed: 3s
#
# ==============================
# run 181
# max_depth: 17
# max_features: 0.405718541552
# min_samples_leaf: 7
#
# 1 - R2 score: 0.130311788311
# elapsed: 3s
#
# ==============================
# run 182
# max_depth: 13
# max_features: 0.500439813695
# min_samples_leaf: 2
#
# 1 - R2 score: 0.12509536994
# elapsed: 4s
#
# ==============================
# run 183
# max_depth: 13
# max_features: 0.378718220308
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12335167595
# elapsed: 4s
#
# ==============================
# run 184
# max_depth: 12
# max_features: 0.318122543956
# min_samples_leaf: 4
#
# 1 - R2 score: 0.126494742977
# elapsed: 3s
#
# ==============================
# run 185
# max_depth: 14
# max_features: 0.265006675517
# min_samples_leaf: 9
#
# 1 - R2 score: 0.135744017331
# elapsed: 2s
#
# ==============================
# run 186
# max_depth: 15
# max_features: 0.126272038729
# min_samples_leaf: 5
#
# 1 - R2 score: 0.136169880699
# elapsed: 2s
#
# ==============================
# run 187
# max_depth: 19
# max_features: 0.422307964165
# min_samples_leaf: 1
#
# 1 - R2 score: 0.117715630833
# elapsed: 5s
#
# ==============================
# run 188
# max_depth: 19
# max_features: 0.653318386498
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122335354804
# elapsed: 6s
#
# ==============================
# run 189
# max_depth: 22
# max_features: 0.427677459659
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124578549256
# elapsed: 4s
#
# ==============================
# run 190
# max_depth: 23
# max_features: 0.518080530227
# min_samples_leaf: 8
#
# 1 - R2 score: 0.135216158498
# elapsed: 3s
#
# ==============================
# run 191
# max_depth: 29
# max_features: 0.443389082113
# min_samples_leaf: 9
#
# 1 - R2 score: 0.137775959731
# elapsed: 3s
#
# ==============================
# run 192
# max_depth: 20
# max_features: 0.559562591819
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122208046543
# elapsed: 5s
#
# ==============================
# run 193
# max_depth: 18
# max_features: 0.216928644729
# min_samples_leaf: 3
#
# 1 - R2 score: 0.122049645276
# elapsed: 3s
#
# ==============================
# run 194
# max_depth: 21
# max_features: 0.337325991171
# min_samples_leaf: 1
#
# 1 - R2 score: 0.118046017514
# elapsed: 4s
#
# ==============================
# run 195
# max_depth: 20
# max_features: 0.582042869942
# min_samples_leaf: 1
#
# 1 - R2 score: 0.125634782813
# elapsed: 6s
#
# ==============================
# run 196
# max_depth: 24
# max_features: 0.36038947031
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125941340042
# elapsed: 3s
#
# ==============================
# run 197
# max_depth: 22
# max_features: 0.611181845205
# min_samples_leaf: 4
#
# 1 - R2 score: 0.128693678888
# elapsed: 4s
#
# ==============================
# run 198
# max_depth: 25
# max_features: 0.465415515947
# min_samples_leaf: 2
#
# 1 - R2 score: 0.119537086867
# elapsed: 4s
#
# ==============================
# run 199
# max_depth: 17
# max_features: 0.288968489889
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120726171839
# elapsed: 4s
#
# ==============================
# run 200
# max_depth: 16
# max_features: 0.415300571123
# min_samples_leaf: 1
#
# 1 - R2 score: 0.121203517259
# elapsed: 5s
#
# Seconds passed: 5146
# {'max_features': 0.3498754943598712, 'max_depth': 12.000704827928411, 'min_samples_leaf': 2.2942811768803453}
