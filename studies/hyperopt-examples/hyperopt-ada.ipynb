# %%
import pandas as pd
import numpy as np
import hyperopt
import os
import sys
import csv

from time import time

from hyperopt import hp, fmin, tpe
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Loading data

# %%
df = pd.read_csv('data/manipulated_train.csv')

# %%
X = df.drop(['SalePrice'], axis=1)
y = df['SalePrice']

# %%
X.shape
# Out:
# (1460, 79)

# %% [markdown]
# ### Setting paratemers

# %%
# Test parameters
max_evals = 200
run_counter = 0
num_cv = 10
n_jobs = -1
output_log_file = '~/temp/hyperopt-ada.csv'

# %%
ada = AdaBoostRegressor()
ada.get_params()
# Out:
# {'base_estimator': None,
#  'learning_rate': 1.0,
#  'loss': 'linear',
#  'n_estimators': 50,
#  'random_state': None}

# %%
tree = DecisionTreeRegressor()
tree.get_params()
# Out:
# {'criterion': 'mse',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_split': 1e-07,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': False,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# Hyperparameters space
space = (
    hp.uniform('max_depth', 5, 30),
    hp.uniform('max_features', 0.1, 1),
    hp.uniform('min_samples_leaf', 1, 10)
)

# %% [markdown]
# ### Function run_wrapper
#
# Just a function for counting and logging experiments, that is called by the hyperopt.fmin(). It also calls the run_test(), the function that indeed execute the experiment for the input parameters.

# %%
def run_wrapper(params):
    global run_counter
    global o_f
    
    run_counter += 1
    print "=============================="
    print "run", run_counter
    
    s = time()
    r2score = run_test(params)
    
    print
    print "1 - R2 score:", r2score
    print "elapsed: {}s \n".format(int(round(time() - s)))
    
    writer.writerow([r2score] + list(params))
    o_f.flush()
    return r2score

# %% [markdown]
# ### Function run_test
#
# The function that receives the parameters, execute the test and return the results. I am using a cross-validation for obtaining the score, and returning it for being optmized by hyperopt.fmin() (therefore I subtracted 1 - score).

# %%
def run_test(params):
    max_depth, max_features, min_samples_leaf = params
    max_depth = int(max_depth)
    min_samples_leaf = int(min_samples_leaf)
    
    print "max_depth:", max_depth
    print "max_features:", max_features
    print "min_samples_leaf:", min_samples_leaf
    
    dt = DecisionTreeRegressor(max_depth=max_depth,
                               max_features=max_features,
                               min_samples_leaf=min_samples_leaf)
    
    ada = AdaBoostRegressor(base_estimator=dt,
                            n_estimators=100,
                            random_state=66)
    
    cvs = cross_val_score(ada, X, y,
                          cv=num_cv,
                          n_jobs=n_jobs)
    
    return 1 - np.median(cvs)

# %% [markdown]
# ### Main function
#
# Just some logging and calling the hyperopt.fmin(). In the end, it obtains the best parameters -- the ones that minimizes the objective function.

# %%
if __name__ == '__main__':
    
    headers = 'r2score max_depth max_features min_samples_leaf'.split()
    o_f = open(output_log_file, 'wb')
    writer = csv.writer(o_f)
    writer.writerow(headers)
    
    start_time = time()
    best = fmin(run_wrapper, space, algo=tpe.suggest, max_evals=max_evals)
    end_time = time()
    
    print "Seconds passed:", int(round(end_time - start_time))
    print best
# Out:
# ==============================
# run 1
# max_depth: 18
# max_features: 0.416766886219
# min_samples_leaf: 3
#
# 1 - R2 score: 0.116134523548
# elapsed: 5s
#
# ==============================
# run 2
# max_depth: 10
# max_features: 0.438866994862
# min_samples_leaf: 6
#
# 1 - R2 score: 0.116478099568
# elapsed: 4s
#
# ==============================
# run 3
# max_depth: 11
# max_features: 0.296154138694
# min_samples_leaf: 5
#
# 1 - R2 score: 0.115709541632
# elapsed: 4s
#
# ==============================
# run 4
# max_depth: 25
# max_features: 0.615929357222
# min_samples_leaf: 6
#
# 1 - R2 score: 0.116574866203
# elapsed: 6s
#
# ==============================
# run 5
# max_depth: 11
# max_features: 0.560843674475
# min_samples_leaf: 1
#
# 1 - R2 score: 0.121499022193
# elapsed: 6s
#
# ==============================
# run 6
# max_depth: 16
# max_features: 0.65350437889
# min_samples_leaf: 3
#
# 1 - R2 score: 0.11123038553
# elapsed: 6s
#
# ==============================
# run 7
# max_depth: 14
# max_features: 0.525612120075
# min_samples_leaf: 9
#
# 1 - R2 score: 0.123636617203
# elapsed: 5s
#
# ==============================
# run 8
# max_depth: 25
# max_features: 0.778970714122
# min_samples_leaf: 5
#
# 1 - R2 score: 0.116115872679
# elapsed: 8s
#
# ==============================
# run 9
# max_depth: 13
# max_features: 0.919535183576
# min_samples_leaf: 5
#
# 1 - R2 score: 0.116574685412
# elapsed: 9s
#
# ==============================
# run 10
# max_depth: 8
# max_features: 0.969602639436
# min_samples_leaf: 6
#
# 1 - R2 score: 0.129905840254
# elapsed: 7s
#
# ==============================
# run 11
# max_depth: 22
# max_features: 0.657800063092
# min_samples_leaf: 5
#
# 1 - R2 score: 0.115385364095
# elapsed: 6s
#
# ==============================
# run 12
# max_depth: 12
# max_features: 0.208972559032
# min_samples_leaf: 2
#
# 1 - R2 score: 0.125615691759
# elapsed: 4s
#
# ==============================
# run 13
# max_depth: 6
# max_features: 0.827604200752
# min_samples_leaf: 8
#
# 1 - R2 score: 0.133814268583
# elapsed: 7s
#
# ==============================
# run 14
# max_depth: 10
# max_features: 0.433635650593
# min_samples_leaf: 5
#
# 1 - R2 score: 0.116930840161
# elapsed: 5s
#
# ==============================
# run 15
# max_depth: 14
# max_features: 0.667768217415
# min_samples_leaf: 3
#
# 1 - R2 score: 0.108895308653
# elapsed: 8s
#
# ==============================
# run 16
# max_depth: 5
# max_features: 0.781209539629
# min_samples_leaf: 8
#
# 1 - R2 score: 0.143725781779
# elapsed: 5s
#
# ==============================
# run 17
# max_depth: 13
# max_features: 0.613221373735
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118165744798
# elapsed: 7s
#
# ==============================
# run 18
# max_depth: 12
# max_features: 0.797471778877
# min_samples_leaf: 4
#
# 1 - R2 score: 0.116795275148
# elapsed: 8s
#
# ==============================
# run 19
# max_depth: 5
# max_features: 0.370726063244
# min_samples_leaf: 2
#
# 1 - R2 score: 0.137846207291
# elapsed: 3s
#
# ==============================
# run 20
# max_depth: 27
# max_features: 0.895104366222
# min_samples_leaf: 1
#
# 1 - R2 score: 0.124614945367
# elapsed: 10s
#
# ==============================
# run 21
# max_depth: 17
# max_features: 0.67439033533
# min_samples_leaf: 3
#
# 1 - R2 score: 0.114454737707
# elapsed: 7s
#
# ==============================
# run 22
# max_depth: 19
# max_features: 0.718448431139
# min_samples_leaf: 4
#
# 1 - R2 score: 0.121583087868
# elapsed: 7s
#
# ==============================
# run 23
# max_depth: 16
# max_features: 0.517490056986
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121262035909
# elapsed: 6s
#
# ==============================
# run 24
# max_depth: 20
# max_features: 0.123635062668
# min_samples_leaf: 4
#
# 1 - R2 score: 0.119880411296
# elapsed: 3s
#
# ==============================
# run 25
# max_depth: 22
# max_features: 0.696302645769
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118409377505
# elapsed: 7s
#
# ==============================
# run 26
# max_depth: 15
# max_features: 0.577084136296
# min_samples_leaf: 7
#
# 1 - R2 score: 0.11749352094
# elapsed: 5s
#
# ==============================
# run 27
# max_depth: 8
# max_features: 0.736155155924
# min_samples_leaf: 1
#
# 1 - R2 score: 0.129693923607
# elapsed: 6s
#
# ==============================
# run 28
# max_depth: 19
# max_features: 0.857683633809
# min_samples_leaf: 2
#
# 1 - R2 score: 0.11792472904
# elapsed: 8s
#
# ==============================
# run 29
# max_depth: 14
# max_features: 0.987724991622
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121566510409
# elapsed: 9s
#
# ==============================
# run 30
# max_depth: 17
# max_features: 0.490881656013
# min_samples_leaf: 4
#
# 1 - R2 score: 0.119943070354
# elapsed: 6s
#
# ==============================
# run 31
# max_depth: 21
# max_features: 0.306197537647
# min_samples_leaf: 4
#
# 1 - R2 score: 0.120882223021
# elapsed: 4s
#
# ==============================
# run 32
# max_depth: 9
# max_features: 0.460263512238
# min_samples_leaf: 3
#
# 1 - R2 score: 0.12467151568
# elapsed: 5s
#
# ==============================
# run 33
# max_depth: 29
# max_features: 0.355886333255
# min_samples_leaf: 7
#
# 1 - R2 score: 0.122852290261
# elapsed: 4s
#
# ==============================
# run 34
# max_depth: 18
# max_features: 0.612586685056
# min_samples_leaf: 9
#
# 1 - R2 score: 0.116592822258
# elapsed: 6s
#
# ==============================
# run 35
# max_depth: 16
# max_features: 0.649498897956
# min_samples_leaf: 2
#
# 1 - R2 score: 0.122498182327
# elapsed: 7s
#
# ==============================
# run 36
# max_depth: 21
# max_features: 0.572247988045
# min_samples_leaf: 1
#
# 1 - R2 score: 0.118161252678
# elapsed: 7s
#
# ==============================
# run 37
# max_depth: 23
# max_features: 0.743431825232
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113156948902
# elapsed: 9s
#
# ==============================
# run 38
# max_depth: 14
# max_features: 0.396269791024
# min_samples_leaf: 5
#
# 1 - R2 score: 0.115302146021
# elapsed: 5s
#
# ==============================
# run 39
# max_depth: 11
# max_features: 0.845572995322
# min_samples_leaf: 2
#
# 1 - R2 score: 0.119716612748
# elapsed: 8s
#
# ==============================
# run 40
# max_depth: 10
# max_features: 0.915356303427
# min_samples_leaf: 3
#
# 1 - R2 score: 0.123123454094
# elapsed: 8s
#
# ==============================
# run 41
# max_depth: 20
# max_features: 0.48410208818
# min_samples_leaf: 7
#
# 1 - R2 score: 0.115935542232
# elapsed: 5s
#
# ==============================
# run 42
# max_depth: 25
# max_features: 0.217178739116
# min_samples_leaf: 6
#
# 1 - R2 score: 0.120722941173
# elapsed: 3s
#
# ==============================
# run 43
# max_depth: 18
# max_features: 0.539130242813
# min_samples_leaf: 1
#
# 1 - R2 score: 0.119540917331
# elapsed: 6s
#
# ==============================
# run 44
# max_depth: 7
# max_features: 0.639477049796
# min_samples_leaf: 3
#
# 1 - R2 score: 0.127680706516
# elapsed: 7s
#
# ==============================
# run 45
# max_depth: 13
# max_features: 0.760394174173
# min_samples_leaf: 1
#
# 1 - R2 score: 0.116144822674
# elapsed: 9s
#
# ==============================
# run 46
# max_depth: 15
# max_features: 0.798141364944
# min_samples_leaf: 4
#
# 1 - R2 score: 0.125878052974
# elapsed: 8s
#
# ==============================
# run 47
# max_depth: 24
# max_features: 0.946402453605
# min_samples_leaf: 7
#
# 1 - R2 score: 0.121330515769
# elapsed: 8s
#
# ==============================
# run 48
# max_depth: 13
# max_features: 0.703716945291
# min_samples_leaf: 6
#
# 1 - R2 score: 0.120692115884
# elapsed: 6s
#
# ==============================
# run 49
# max_depth: 11
# max_features: 0.597951066617
# min_samples_leaf: 5
#
# 1 - R2 score: 0.116311262602
# elapsed: 5s
#
# ==============================
# run 50
# max_depth: 6
# max_features: 0.301552143386
# min_samples_leaf: 3
#
# 1 - R2 score: 0.134991529122
# elapsed: 3s
#
# ==============================
# run 51
# max_depth: 27
# max_features: 0.886663793906
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115366505128
# elapsed: 9s
#
# ==============================
# run 52
# max_depth: 10
# max_features: 0.815342165893
# min_samples_leaf: 3
#
# 1 - R2 score: 0.124045095481
# elapsed: 7s
#
# ==============================
# run 53
# max_depth: 16
# max_features: 0.677411525274
# min_samples_leaf: 1
#
# 1 - R2 score: 0.121112590887
# elapsed: 7s
#
# ==============================
# run 54
# max_depth: 20
# max_features: 0.109825179744
# min_samples_leaf: 4
#
# 1 - R2 score: 0.124714493255
# elapsed: 2s
#
# ==============================
# run 55
# max_depth: 12
# max_features: 0.226860881318
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120563181973
# elapsed: 3s
#
# ==============================
# run 56
# max_depth: 23
# max_features: 0.419583316955
# min_samples_leaf: 8
#
# 1 - R2 score: 0.115702941063
# elapsed: 4s
#
# ==============================
# run 57
# max_depth: 14
# max_features: 0.16233658075
# min_samples_leaf: 5
#
# 1 - R2 score: 0.123586353032
# elapsed: 4s
#
# ==============================
# run 58
# max_depth: 26
# max_features: 0.519895594884
# min_samples_leaf: 1
#
# 1 - R2 score: 0.11943781537
# elapsed: 8s
#
# ==============================
# run 59
# max_depth: 19
# max_features: 0.338188526977
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123420570431
# elapsed: 6s
#
# ==============================
# run 60
# max_depth: 17
# max_features: 0.771875387993
# min_samples_leaf: 6
#
# 1 - R2 score: 0.116438703355
# elapsed: 8s
#
# ==============================
# run 61
# max_depth: 15
# max_features: 0.953938701011
# min_samples_leaf: 4
#
# 1 - R2 score: 0.127431516895
# elapsed: 10s
#
# ==============================
# run 62
# max_depth: 9
# max_features: 0.454009456152
# min_samples_leaf: 3
#
# 1 - R2 score: 0.119713392682
# elapsed: 5s
#
# ==============================
# run 63
# max_depth: 7
# max_features: 0.258562449954
# min_samples_leaf: 9
#
# 1 - R2 score: 0.131463370829
# elapsed: 3s
#
# ==============================
# run 64
# max_depth: 13
# max_features: 0.862687124834
# min_samples_leaf: 3
#
# 1 - R2 score: 0.119590873506
# elapsed: 9s
#
# ==============================
# run 65
# max_depth: 11
# max_features: 0.583211181663
# min_samples_leaf: 4
#
# 1 - R2 score: 0.122437148938
# elapsed: 6s
#
# ==============================
# run 66
# max_depth: 24
# max_features: 0.728773757762
# min_samples_leaf: 1
#
# 1 - R2 score: 0.116465703599
# elapsed: 9s
#
# ==============================
# run 67
# max_depth: 23
# max_features: 0.750440812519
# min_samples_leaf: 1
#
# 1 - R2 score: 0.123847071599
# elapsed: 9s
#
# ==============================
# run 68
# max_depth: 29
# max_features: 0.63143843538
# min_samples_leaf: 3
#
# 1 - R2 score: 0.112087248937
# elapsed: 7s
#
# ==============================
# run 69
# max_depth: 21
# max_features: 0.640107932361
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116736124386
# elapsed: 7s
#
# ==============================
# run 70
# max_depth: 18
# max_features: 0.553574862643
# min_samples_leaf: 3
#
# 1 - R2 score: 0.117531021009
# elapsed: 6s
#
# ==============================
# run 71
# max_depth: 29
# max_features: 0.680536812963
# min_samples_leaf: 2
#
# 1 - R2 score: 0.113594158929
# elapsed: 8s
#
# ==============================
# run 72
# max_depth: 22
# max_features: 0.495304621963
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116509535737
# elapsed: 6s
#
# ==============================
# run 73
# max_depth: 28
# max_features: 0.619183203848
# min_samples_leaf: 5
#
# 1 - R2 score: 0.124771878628
# elapsed: 6s
#
# ==============================
# run 74
# max_depth: 16
# max_features: 0.710584995724
# min_samples_leaf: 4
#
# 1 - R2 score: 0.117072818891
# elapsed: 7s
#
# ==============================
# run 75
# max_depth: 16
# max_features: 0.389375317026
# min_samples_leaf: 5
#
# 1 - R2 score: 0.115504592918
# elapsed: 4s
#
# ==============================
# run 76
# max_depth: 15
# max_features: 0.810132011527
# min_samples_leaf: 3
#
# 1 - R2 score: 0.128299486948
# elapsed: 8s
#
# ==============================
# run 77
# max_depth: 18
# max_features: 0.665455566146
# min_samples_leaf: 4
#
# 1 - R2 score: 0.116125790301
# elapsed: 8s
#
# ==============================
# run 78
# max_depth: 10
# max_features: 0.53673502745
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116171359926
# elapsed: 6s
#
# ==============================
# run 79
# max_depth: 14
# max_features: 0.83856554567
# min_samples_leaf: 2
#
# 1 - R2 score: 0.121984245366
# elapsed: 8s
#
# ==============================
# run 80
# max_depth: 5
# max_features: 0.595508886845
# min_samples_leaf: 5
#
# 1 - R2 score: 0.140102746987
# elapsed: 4s
#
# ==============================
# run 81
# max_depth: 20
# max_features: 0.558046614401
# min_samples_leaf: 3
#
# 1 - R2 score: 0.118208924561
# elapsed: 6s
#
# ==============================
# run 82
# max_depth: 25
# max_features: 0.62924206355
# min_samples_leaf: 4
#
# 1 - R2 score: 0.118855807805
# elapsed: 7s
#
# ==============================
# run 83
# max_depth: 26
# max_features: 0.501393298616
# min_samples_leaf: 1
#
# 1 - R2 score: 0.116882109824
# elapsed: 7s
#
# ==============================
# run 84
# max_depth: 19
# max_features: 0.455599461554
# min_samples_leaf: 3
#
# 1 - R2 score: 0.115572947006
# elapsed: 5s
#
# ==============================
# run 85
# max_depth: 13
# max_features: 0.691493978309
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117253210641
# elapsed: 8s
#
# ==============================
# run 86
# max_depth: 9
# max_features: 0.784764092761
# min_samples_leaf: 1
#
# 1 - R2 score: 0.128610518204
# elapsed: 7s
#
# ==============================
# run 87
# max_depth: 6
# max_features: 0.876438152998
# min_samples_leaf: 1
#
# 1 - R2 score: 0.1393239727
# elapsed: 7s
#
# ==============================
# run 88
# max_depth: 8
# max_features: 0.714909485136
# min_samples_leaf: 4
#
# 1 - R2 score: 0.124697711554
# elapsed: 8s
#
# ==============================
# run 89
# max_depth: 11
# max_features: 0.475524404266
# min_samples_leaf: 5
#
# 1 - R2 score: 0.117915898496
# elapsed: 6s
#
# ==============================
# run 90
# max_depth: 20
# max_features: 0.991502105644
# min_samples_leaf: 3
#
# 1 - R2 score: 0.120841252661
# elapsed: 12s
#
# ==============================
# run 91
# max_depth: 17
# max_features: 0.657158767614
# min_samples_leaf: 4
#
# 1 - R2 score: 0.121256804242
# elapsed: 6s
#
# ==============================
# run 92
# max_depth: 16
# max_features: 0.334853431569
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117045429965
# elapsed: 5s
#
# ==============================
# run 93
# max_depth: 15
# max_features: 0.60126553627
# min_samples_leaf: 7
#
# 1 - R2 score: 0.12270256167
# elapsed: 5s
#
# ==============================
# run 94
# max_depth: 14
# max_features: 0.574308509064
# min_samples_leaf: 1
#
# 1 - R2 score: 0.117577556671
# elapsed: 8s
#
# ==============================
# run 95
# max_depth: 23
# max_features: 0.915419417627
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121595385158
# elapsed: 10s
#
# ==============================
# run 96
# max_depth: 12
# max_features: 0.736031930556
# min_samples_leaf: 6
#
# 1 - R2 score: 0.122190009323
# elapsed: 8s
#
# ==============================
# run 97
# max_depth: 10
# max_features: 0.519334283246
# min_samples_leaf: 5
#
# 1 - R2 score: 0.115982985562
# elapsed: 5s
#
# ==============================
# run 98
# max_depth: 13
# max_features: 0.431307521782
# min_samples_leaf: 5
#
# 1 - R2 score: 0.118022853231
# elapsed: 5s
#
# ==============================
# run 99
# max_depth: 18
# max_features: 0.404458585462
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120349230775
# elapsed: 6s
#
# ==============================
# run 100
# max_depth: 18
# max_features: 0.767718737032
# min_samples_leaf: 6
#
# 1 - R2 score: 0.126472836274
# elapsed: 8s
#
# ==============================
# run 101
# max_depth: 29
# max_features: 0.819629876709
# min_samples_leaf: 3
#
# 1 - R2 score: 0.114599718977
# elapsed: 9s
#
# ==============================
# run 102
# max_depth: 22
# max_features: 0.793127703005
# min_samples_leaf: 1
#
# 1 - R2 score: 0.119281285541
# elapsed: 10s
#
# ==============================
# run 103
# max_depth: 8
# max_features: 0.692424469497
# min_samples_leaf: 1
#
# 1 - R2 score: 0.127411946107
# elapsed: 6s
#
# ==============================
# run 104
# max_depth: 12
# max_features: 0.642847536086
# min_samples_leaf: 4
#
# 1 - R2 score: 0.113695180784
# elapsed: 6s
#
# ==============================
# run 105
# max_depth: 24
# max_features: 0.941620429322
# min_samples_leaf: 9
#
# 1 - R2 score: 0.118749436714
# elapsed: 8s
#
# ==============================
# run 106
# max_depth: 28
# max_features: 0.539722683789
# min_samples_leaf: 3
#
# 1 - R2 score: 0.118497437316
# elapsed: 6s
#
# ==============================
# run 107
# max_depth: 16
# max_features: 0.375087913455
# min_samples_leaf: 2
#
# 1 - R2 score: 0.124126015956
# elapsed: 5s
#
# ==============================
# run 108
# max_depth: 19
# max_features: 0.617010676024
# min_samples_leaf: 4
#
# 1 - R2 score: 0.114004622681
# elapsed: 6s
#
# ==============================
# run 109
# max_depth: 21
# max_features: 0.269917219253
# min_samples_leaf: 2
#
# 1 - R2 score: 0.115318089711
# elapsed: 4s
#
# ==============================
# run 110
# max_depth: 10
# max_features: 0.477999913961
# min_samples_leaf: 1
#
# 1 - R2 score: 0.120710167832
# elapsed: 6s
#
# ==============================
# run 111
# max_depth: 16
# max_features: 0.666470293452
# min_samples_leaf: 8
#
# 1 - R2 score: 0.121034785255
# elapsed: 6s
#
# ==============================
# run 112
# max_depth: 15
# max_features: 0.895021734589
# min_samples_leaf: 5
#
# 1 - R2 score: 0.123504856026
# elapsed: 8s
#
# ==============================
# run 113
# max_depth: 11
# max_features: 0.753341691513
# min_samples_leaf: 4
#
# 1 - R2 score: 0.117606099428
# elapsed: 7s
#
# ==============================
# run 114
# max_depth: 20
# max_features: 0.855883108863
# min_samples_leaf: 2
#
# 1 - R2 score: 0.112307049764
# elapsed: 9s
#
# ==============================
# run 115
# max_depth: 27
# max_features: 0.50797558192
# min_samples_leaf: 3
#
# 1 - R2 score: 0.117522760749
# elapsed: 6s
#
# ==============================
# run 116
# max_depth: 7
# max_features: 0.57697238857
# min_samples_leaf: 2
#
# 1 - R2 score: 0.127503035552
# elapsed: 4s
#
# ==============================
# run 117
# max_depth: 13
# max_features: 0.725166574421
# min_samples_leaf: 1
#
# 1 - R2 score: 0.113566740986
# elapsed: 9s
#
# ==============================
# run 118
# max_depth: 13
# max_features: 0.178978069407
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118768303878
# elapsed: 3s
#
# ==============================
# run 119
# max_depth: 14
# max_features: 0.833208346229
# min_samples_leaf: 4
#
# 1 - R2 score: 0.121989852591
# elapsed: 7s
#
# ==============================
# run 120
# max_depth: 17
# max_features: 0.440023707284
# min_samples_leaf: 3
#
# 1 - R2 score: 0.114980394854
# elapsed: 5s
#
# ==============================
# run 121
# max_depth: 23
# max_features: 0.626759131626
# min_samples_leaf: 1
#
# 1 - R2 score: 0.122111397699
# elapsed: 7s
#
# ==============================
# run 122
# max_depth: 26
# max_features: 0.968637844379
# min_samples_leaf: 5
#
# 1 - R2 score: 0.117970892081
# elapsed: 10s
#
# ==============================
# run 123
# max_depth: 19
# max_features: 0.595735060299
# min_samples_leaf: 4
#
# 1 - R2 score: 0.119306729959
# elapsed: 6s
#
# ==============================
# run 124
# max_depth: 18
# max_features: 0.798422749804
# min_samples_leaf: 3
#
# 1 - R2 score: 0.114457145877
# elapsed: 8s
#
# ==============================
# run 125
# max_depth: 18
# max_features: 0.557396115398
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121406861072
# elapsed: 6s
#
# ==============================
# run 126
# max_depth: 9
# max_features: 0.704625767103
# min_samples_leaf: 6
#
# 1 - R2 score: 0.12001085184
# elapsed: 6s
#
# ==============================
# run 127
# max_depth: 17
# max_features: 0.674977139281
# min_samples_leaf: 5
#
# 1 - R2 score: 0.114173858846
# elapsed: 7s
#
# ==============================
# run 128
# max_depth: 24
# max_features: 0.53878044911
# min_samples_leaf: 4
#
# 1 - R2 score: 0.117441362186
# elapsed: 6s
#
# ==============================
# run 129
# max_depth: 5
# max_features: 0.872645631787
# min_samples_leaf: 2
#
# 1 - R2 score: 0.144239175574
# elapsed: 5s
#
# ==============================
# run 130
# max_depth: 21
# max_features: 0.342574183434
# min_samples_leaf: 3
#
# 1 - R2 score: 0.119824644517
# elapsed: 5s
#
# ==============================
# run 131
# max_depth: 8
# max_features: 0.748250311345
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120410450686
# elapsed: 6s
#
# ==============================
# run 132
# max_depth: 15
# max_features: 0.6562313664
# min_samples_leaf: 1
#
# 1 - R2 score: 0.121631930214
# elapsed: 7s
#
# ==============================
# run 133
# max_depth: 12
# max_features: 0.683602725163
# min_samples_leaf: 7
#
# 1 - R2 score: 0.121802433276
# elapsed: 6s
#
# ==============================
# run 134
# max_depth: 15
# max_features: 0.611329478196
# min_samples_leaf: 2
#
# 1 - R2 score: 0.117880006937
# elapsed: 7s
#
# ==============================
# run 135
# max_depth: 23
# max_features: 0.470697178315
# min_samples_leaf: 6
#
# 1 - R2 score: 0.121890746511
# elapsed: 5s
#
# ==============================
# run 136
# max_depth: 16
# max_features: 0.936000022821
# min_samples_leaf: 5
#
# 1 - R2 score: 0.119638407342
# elapsed: 8s
#
# ==============================
# run 137
# max_depth: 21
# max_features: 0.771272191612
# min_samples_leaf: 1
#
# 1 - R2 score: 0.121883880118
# elapsed: 9s
#
# ==============================
# run 138
# max_depth: 20
# max_features: 0.638454207478
# min_samples_leaf: 5
#
# 1 - R2 score: 0.124937131946
# elapsed: 6s
#
# ==============================
# run 139
# max_depth: 14
# max_features: 0.419166754978
# min_samples_leaf: 3
#
# 1 - R2 score: 0.117041309562
# elapsed: 5s
#
# ==============================
# run 140
# max_depth: 25
# max_features: 0.580299174237
# min_samples_leaf: 1
#
# 1 - R2 score: 0.125909215716
# elapsed: 8s
#
# ==============================
# run 141
# max_depth: 6
# max_features: 0.736466940993
# min_samples_leaf: 1
#
# 1 - R2 score: 0.135199950638
# elapsed: 5s
#
# ==============================
# run 142
# max_depth: 22
# max_features: 0.711954728621
# min_samples_leaf: 4
#
# 1 - R2 score: 0.117579061328
# elapsed: 7s
#
# ==============================
# run 143
# max_depth: 28
# max_features: 0.523134731862
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118840892887
# elapsed: 7s
#
# ==============================
# run 144
# max_depth: 17
# max_features: 0.379986592486
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118421022542
# elapsed: 5s
#
# ==============================
# run 145
# max_depth: 17
# max_features: 0.491280366962
# min_samples_leaf: 4
#
# 1 - R2 score: 0.119943070354
# elapsed: 6s
#
# ==============================
# run 146
# max_depth: 13
# max_features: 0.841931265673
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118720941662
# elapsed: 8s
#
# ==============================
# run 147
# max_depth: 11
# max_features: 0.899081185118
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123407697974
# elapsed: 9s
#
# ==============================
# run 148
# max_depth: 18
# max_features: 0.96927210595
# min_samples_leaf: 2
#
# 1 - R2 score: 0.12258344589
# elapsed: 11s
#
# ==============================
# run 149
# max_depth: 20
# max_features: 0.791283766254
# min_samples_leaf: 3
#
# 1 - R2 score: 0.11832349495
# elapsed: 9s
#
# ==============================
# run 150
# max_depth: 28
# max_features: 0.856120779838
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121278484083
# elapsed: 8s
#
# ==============================
# run 151
# max_depth: 29
# max_features: 0.911541424327
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121595385158
# elapsed: 9s
#
# ==============================
# run 152
# max_depth: 27
# max_features: 0.815182002526
# min_samples_leaf: 2
#
# 1 - R2 score: 0.116316124597
# elapsed: 8s
#
# ==============================
# run 153
# max_depth: 25
# max_features: 0.76326223098
# min_samples_leaf: 3
#
# 1 - R2 score: 0.121412920161
# elapsed: 8s
#
# ==============================
# run 154
# max_depth: 19
# max_features: 0.564529932465
# min_samples_leaf: 2
#
# 1 - R2 score: 0.118159462804
# elapsed: 6s
#
# ==============================
# run 155
# max_depth: 14
# max_features: 0.589015490336
# min_samples_leaf: 1
#
# 1 - R2 score: 0.119809621151
# elapsed: 7s
#
# ==============================
# run 156
# max_depth: 29
# max_features: 0.654737051575
# min_samples_leaf: 1
#
# 1 - R2 score: 0.123803148837
# elapsed: 7s
#
# ==============================
# run 157
# max_depth: 19
# max_features: 0.698466698034
# min_samples_leaf: 4
#
# 1 - R2 score: 0.121799495423
# elapsed: 7s
#
# ==============================
# run 158
# max_depth: 25
# max_features: 0.7277510558
# min_samples_leaf: 1
#
# 1 - R2 score: 0.114284167458
# elapsed: 10s
#
# ==============================
# run 159
# max_depth: 16
# max_features: 0.991342327459
# min_samples_leaf: 2
#
# 1 - R2 score: 0.114000046012
# elapsed: 10s
#
# ==============================
# run 160
# max_depth: 15
# max_features: 0.860907721429
# min_samples_leaf: 3
#
# 1 - R2 score: 0.115724027917
# elapsed: 8s
#
# ==============================
# run 161
# max_depth: 23
# max_features: 0.614130411748
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120638628831
# elapsed: 8s
#
# ==============================
# run 162
# max_depth: 28
# max_features: 0.445302921273
# min_samples_leaf: 1
#
# 1 - R2 score: 0.112280103255
# elapsed: 6s
#
# ==============================
# run 163
# max_depth: 27
# max_features: 0.445037549996
# min_samples_leaf: 1
#
# 1 - R2 score: 0.112280103255
# elapsed: 6s
#
# ==============================
# run 164
# max_depth: 24
# max_features: 0.395187450375
# min_samples_leaf: 4
#
# 1 - R2 score: 0.115833589572
# elapsed: 5s
#
# ==============================
# run 165
# max_depth: 27
# max_features: 0.551345403077
# min_samples_leaf: 1
#
# 1 - R2 score: 0.118597890759
# elapsed: 7s
#
# ==============================
# run 166
# max_depth: 26
# max_features: 0.314860309022
# min_samples_leaf: 4
#
# 1 - R2 score: 0.113266944429
# elapsed: 4s
#
# ==============================
# run 167
# max_depth: 12
# max_features: 0.246421491814
# min_samples_leaf: 6
#
# 1 - R2 score: 0.120422173295
# elapsed: 3s
#
# ==============================
# run 168
# max_depth: 28
# max_features: 0.506222115852
# min_samples_leaf: 5
#
# 1 - R2 score: 0.116361263887
# elapsed: 5s
#
# ==============================
# run 169
# max_depth: 10
# max_features: 0.283461645706
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12271753415
# elapsed: 4s
#
# ==============================
# run 170
# max_depth: 13
# max_features: 0.364802015531
# min_samples_leaf: 3
#
# 1 - R2 score: 0.116824066639
# elapsed: 5s
#
# ==============================
# run 171
# max_depth: 29
# max_features: 0.467722166329
# min_samples_leaf: 1
#
# 1 - R2 score: 0.120655036735
# elapsed: 6s
#
# ==============================
# run 172
# max_depth: 21
# max_features: 0.136923438144
# min_samples_leaf: 9
#
# 1 - R2 score: 0.126147496788
# elapsed: 2s
#
# ==============================
# run 173
# max_depth: 10
# max_features: 0.316704234207
# min_samples_leaf: 3
#
# 1 - R2 score: 0.11764838689
# elapsed: 4s
#
# ==============================
# run 174
# max_depth: 19
# max_features: 0.526573150348
# min_samples_leaf: 3
#
# 1 - R2 score: 0.119444774462
# elapsed: 7s
#
# ==============================
# run 175
# max_depth: 28
# max_features: 0.430283335376
# min_samples_leaf: 8
#
# 1 - R2 score: 0.115702941063
# elapsed: 4s
#
# ==============================
# run 176
# max_depth: 29
# max_features: 0.629457282538
# min_samples_leaf: 1
#
# 1 - R2 score: 0.12021348461
# elapsed: 7s
#
# ==============================
# run 177
# max_depth: 15
# max_features: 0.409634260417
# min_samples_leaf: 3
#
# 1 - R2 score: 0.117827699429
# elapsed: 5s
#
# ==============================
# run 178
# max_depth: 11
# max_features: 0.602218729167
# min_samples_leaf: 7
#
# 1 - R2 score: 0.122516628582
# elapsed: 5s
#
# ==============================
# run 179
# max_depth: 27
# max_features: 0.670418752884
# min_samples_leaf: 4
#
# 1 - R2 score: 0.119291747309
# elapsed: 6s
#
# ==============================
# run 180
# max_depth: 17
# max_features: 0.487644065435
# min_samples_leaf: 2
#
# 1 - R2 score: 0.113362147059
# elapsed: 5s
#
# ==============================
# run 181
# max_depth: 14
# max_features: 0.453546957513
# min_samples_leaf: 6
#
# 1 - R2 score: 0.118268022924
# elapsed: 4s
#
# ==============================
# run 182
# max_depth: 15
# max_features: 0.564985328374
# min_samples_leaf: 3
#
# 1 - R2 score: 0.120819691055
# elapsed: 6s
#
# ==============================
# run 183
# max_depth: 17
# max_features: 0.351211986648
# min_samples_leaf: 2
#
# 1 - R2 score: 0.120134064909
# elapsed: 4s
#
# ==============================
# run 184
# max_depth: 26
# max_features: 0.644839599688
# min_samples_leaf: 2
#
# 1 - R2 score: 0.123819265833
# elapsed: 7s
#
# ==============================
# run 185
# max_depth: 18
# max_features: 0.538239685603
# min_samples_leaf: 1
#
# 1 - R2 score: 0.119540917331
# elapsed: 6s
#
# ==============================
# run 186
# max_depth: 25
# max_features: 0.692767545444
# min_samples_leaf: 6
#
# 1 - R2 score: 0.122360227964
# elapsed: 6s
#
# ==============================
# run 187
# max_depth: 9
# max_features: 0.497477777413
# min_samples_leaf: 2
#
# 1 - R2 score: 0.119250604952
# elapsed: 5s
#
# ==============================
# run 188
# max_depth: 8
# max_features: 0.77891557827
# min_samples_leaf: 3
#
# 1 - R2 score: 0.125980978974
# elapsed: 6s
#
# ==============================
# run 189
# max_depth: 20
# max_features: 0.589718300229
# min_samples_leaf: 1
#
# 1 - R2 score: 0.111546601061
# elapsed: 7s
#
# ==============================
# run 190
# max_depth: 21
# max_features: 0.741960618499
# min_samples_leaf: 2
#
# 1 - R2 score: 0.112370521355
# elapsed: 7s
#
# ==============================
# run 191
# max_depth: 22
# max_features: 0.58134878551
# min_samples_leaf: 4
#
# 1 - R2 score: 0.115190409023
# elapsed: 5s
#
# ==============================
# run 192
# max_depth: 13
# max_features: 0.67736889779
# min_samples_leaf: 4
#
# 1 - R2 score: 0.116876768223
# elapsed: 6s
#
# ==============================
# run 193
# max_depth: 20
# max_features: 0.71425346832
# min_samples_leaf: 3
#
# 1 - R2 score: 0.114341628998
# elapsed: 7s
#
# ==============================
# run 194
# max_depth: 7
# max_features: 0.656419647371
# min_samples_leaf: 1
#
# 1 - R2 score: 0.1304133055
# elapsed: 5s
#
# ==============================
# run 195
# max_depth: 13
# max_features: 0.623071684385
# min_samples_leaf: 3
#
# 1 - R2 score: 0.116897606994
# elapsed: 6s
#
# ==============================
# run 196
# max_depth: 16
# max_features: 0.807575284486
# min_samples_leaf: 2
#
# 1 - R2 score: 0.12079459361
# elapsed: 8s
#
# ==============================
# run 197
# max_depth: 12
# max_features: 0.756596051292
# min_samples_leaf: 1
#
# 1 - R2 score: 0.118557617525
# elapsed: 7s
#
# ==============================
# run 198
# max_depth: 22
# max_features: 0.604293622633
# min_samples_leaf: 4
#
# 1 - R2 score: 0.118652288235
# elapsed: 6s
#
# ==============================
# run 199
# max_depth: 15
# max_features: 0.637961635113
# min_samples_leaf: 3
#
# 1 - R2 score: 0.117826563844
# elapsed: 7s
#
# ==============================
# run 200
# max_depth: 21
# max_features: 0.551327040592
# min_samples_leaf: 1
#
# 1 - R2 score: 0.116258034403
# elapsed: 7s
#
# Seconds passed: 1284
# {'max_features': 0.6677682174152484, 'max_depth': 14.463752090125876, 'min_samples_leaf': 3.19016007481179}
