# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt

IDIR = 'data/'

# %%
priors = pd.read_csv(IDIR + 'order_products__prior.csv',
                     dtype={
                         'order_id': np.int32,
                         'product_id': np.uint16,
                         'add_to_cart_order': np.int16,
                         'reordered': np.int8})

orders = pd.read_csv(IDIR + 'orders.csv',
                     dtype={
                         'order_id': np.int32,
                         'user_id': np.int32,
                         'eval_set': 'category',
                         'order_number': np.int16,
                         'order_dow': np.int8,
                         'order_hour_of_day': np.int8,
                         'days_since_prior_order': np.float32},
                     nrows=10)

products = pd.read_csv(IDIR + 'products.csv',
                       dtype={
                           'product_id': np.uint16,
                           'product_name': object,
                           'aisle_id': np.uint8,
                           'department_id': np.uint8})

# %%
df = orders.merge(priors, on='order_id').merge(products, on='product_id')

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id'],
#       dtype='object')

# %%
df[['user_id', 'order_id', 'order_number', 'days_since_prior_order', 'order_hour_of_day', 'product_name', 'reordered', 'aisle_id']].sort_values(['order_number'])
# Out:
#     user_id  order_id  order_number  days_since_prior_order  \
# 0         1   2539329             1                     NaN
# 23        1   2539329             1                     NaN
# 21        1   2539329             1                     NaN
# 11        1   2539329             1                     NaN
# 10        1   2539329             1                     NaN
# 25        1   2398795             2                    15.0
# 22        1   2398795             2                    15.0
# 36        1   2398795             2                    15.0
# 12        1   2398795             2                    15.0
# 34        1   2398795             2                    15.0
# 1         1   2398795             2                    15.0
# 47        1    473747             3                    21.0
# 26        1    473747             3                    21.0
# 13        1    473747             3                    21.0
# 2         1    473747             3                    21.0
# ...
